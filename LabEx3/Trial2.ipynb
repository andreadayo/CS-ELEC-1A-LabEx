# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Preprocessing and Cleaning

# %%
from pathlib import Path
import imghdr
import os

data_dir = "hair_types"
image_extensions = [".png", ".jpg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]

for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        if filepath.exists():  # Check if the file exists before opening it
            img_type = imghdr.what(filepath)
            if img_type is None:
                print(f"{filepath} is not an image")
                os.remove(filepath)
            elif img_type not in img_type_accepted_by_tf:
                print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
                os.remove(filepath)
        else:
            print(f"{filepath} does not exist.")
# Out:
# hair_types\Straight_Hair\graphicstock-young-handsome-asiatic-long-brown-straight-hair-woman-taking-selfie-outdoor-in-the-city-with-a-smartphone-smiling-vanity-technology-social-network-concept_B6fyU2Ok-_SB_PM.jpg does not exist.
# hair_types\Straight_Hair\graphicstock-young-handsome-caucasian-reddish-straight-hair-woman-sitting-on-a-small-wall-holding-a-tablet-taking-a-selfie-doing-grimace-technology-social-network-youthful-concept_BTFpe2_1W_SB_PM.jpg does not exist.

# %% [markdown]
# # Data Loading and Splitting

# %% [markdown]
# 1ADDED: test_ds

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

image_size = (64, 64)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical'
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size, 
    labels='inferred',
    label_mode='categorical'
)
# Out:
# Found 981 files belonging to 3 classes.
# Using 785 files for training.
# Found 981 files belonging to 3 classes.
# Using 196 files for validation.

# %%
class_names = train_ds.class_names

# Count the number of samples per class in the training set
for class_name in class_names:
    num_samples = len([filename for filename in train_ds.file_paths if class_name in filename])
    print(f"Number of {class_name} samples in the training set: {num_samples}")

# Count the number of samples per class in the validation set
for class_name in class_names:
    num_samples = len([filename for filename in val_ds.file_paths if class_name in filename])
    print(f"Number of {class_name} samples in the validation set: {num_samples}")
# Out:
# Number of Curly_Hair samples in the training set: 276
# Number of Straight_Hair samples in the training set: 250
# Number of Wavy_Hair samples in the training set: 259
# Number of Curly_Hair samples in the validation set: 56
# Number of Straight_Hair samples in the validation set: 68
# Number of Wavy_Hair samples in the validation set: 72

# %% [markdown]
# # Mixed Precision Training and Data Prefetching

# %% [markdown]
# 1ADDED: Mixed Precision Training -  speed up training without sacrificing much in terms of accuracy

# %%
policy = tf.keras.mixed_precision.Policy('mixed_float16')
tf.keras.mixed_precision.set_global_policy(policy)

# %% [markdown]
# 1ADDED: Use the prefetch transformation to overlap the preprocessing and model execution of training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Visualization of Training Data

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(np.argmax(labels[i])))
        plt.axis("off")
plt.show()

# %% [markdown]
# # Model Architecture

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(keras.Input(shape=image_size + (3,))) # 64, 64, 3
model.add(layers.Rescaling(1.0 / 255))

model.add(layers.Conv2D(filters=4, kernel_size=16, strides=1, padding='valid', dilation_rate=2))
model.add(layers.Activation("relu"))

model.add(layers.Conv2D(filters=8, kernel_size=8, strides=1, padding='valid', dilation_rate=2))
model.add(layers.Activation("relu"))

model.add(layers.Conv2D(filters=16, kernel_size=4, strides=1, padding='valid', dilation_rate=2))
model.add(layers.Activation("relu"))

model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(64))
model.add(layers.Activation("relu"))
model.add(layers.Dense(3))
model.add(layers.Activation("softmax"))

# %% [markdown]
# # Visualizing Model Architecture

# %%
tf.keras.utils.plot_model(model, to_file='model_test.png', show_shapes=True)

# %% [markdown]
# # Display Model Summary

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_4 (Rescaling)     (None, 64, 64, 3)         0
#
#  conv2d_12 (Conv2D)          (None, 34, 34, 4)         3076
#
#  activation_20 (Activation)  (None, 34, 34, 4)         0
#
#  conv2d_13 (Conv2D)          (None, 20, 20, 8)         2056
#
#  activation_21 (Activation)  (None, 20, 20, 8)         0
#
#  conv2d_14 (Conv2D)          (None, 14, 14, 16)        2064
#
#  activation_22 (Activation)  (None, 14, 14, 16)        0
#
#  global_average_pooling2d_4  (None, 16)                0
#   (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 64)                1088
#
#  activation_23 (Activation)  (None, 64)                0
#
#  dense_9 (Dense)             (None, 3)                 195
#
#  activation_24 (Activation)  (None, 3)                 0
#
# =================================================================
# Total params: 8479 (33.12 KB)
# Trainable params: 8479 (33.12 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Model Training

# %%
epochs = 30

model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()],
)

# %% [markdown]
# # Training the Model

# %%
history = model.fit(train_ds, epochs=epochs, validation_data=val_ds)
# Out:
# Epoch 1/30
# 25/25 [==============================] - 61s 2s/step - loss: 1.0992 - accuracy: 0.3567 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - auc_6: 0.5112 - val_loss: 1.1008 - val_accuracy: 0.2857 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00 - val_auc_6: 0.4681
# Epoch 2/30
# 25/25 [==============================] - 72s 3s/step - loss: 1.0971 - accuracy: 0.3516 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - auc_6: 0.5212 - val_loss: 1.1028 - val_accuracy: 0.2857 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00 - val_auc_6: 0.4869
# Epoch 3/30
# 25/25 [==============================] - 64s 3s/step - loss: 1.0880 - accuracy: 0.3516 - precision_6: 0.6154 - recall_6: 0.0102 - auc_6: 0.5474 - val_loss: 1.0940 - val_accuracy: 0.2857 - val_precision_6: 0.4000 - val_recall_6: 0.0204 - val_auc_6: 0.4871
# Epoch 4/30
# 25/25 [==============================] - 71s 3s/step - loss: 1.0635 - accuracy: 0.4446 - precision_6: 0.6000 - recall_6: 0.0688 - auc_6: 0.6231 - val_loss: 1.0883 - val_accuracy: 0.4031 - val_precision_6: 0.4000 - val_recall_6: 0.0306 - val_auc_6: 0.5732
# Epoch 5/30
# 25/25 [==============================] - 61s 2s/step - loss: 1.0548 - accuracy: 0.4713 - precision_6: 0.5664 - recall_6: 0.1032 - auc_6: 0.6514 - val_loss: 1.0709 - val_accuracy: 0.4439 - val_precision_6: 0.3333 - val_recall_6: 0.0153 - val_auc_6: 0.6016
# Epoch 6/30
# 25/25 [==============================] - 68s 3s/step - loss: 1.0296 - accuracy: 0.4790 - precision_6: 0.6600 - recall_6: 0.0841 - auc_6: 0.6637 - val_loss: 1.0793 - val_accuracy: 0.3571 - val_precision_6: 0.4762 - val_recall_6: 0.1531 - val_auc_6: 0.5821
# Epoch 7/30
# 25/25 [==============================] - 70s 3s/step - loss: 1.0206 - accuracy: 0.4892 - precision_6: 0.5325 - recall_6: 0.1567 - auc_6: 0.6704 - val_loss: 1.0568 - val_accuracy: 0.3929 - val_precision_6: 0.4412 - val_recall_6: 0.0765 - val_auc_6: 0.6026
# Epoch 8/30
# 25/25 [==============================] - 72s 3s/step - loss: 1.0088 - accuracy: 0.4803 - precision_6: 0.5777 - recall_6: 0.1847 - auc_6: 0.6803 - val_loss: 1.0522 - val_accuracy: 0.4439 - val_precision_6: 0.5714 - val_recall_6: 0.0204 - val_auc_6: 0.6302
# Epoch 9/30
# 25/25 [==============================] - 63s 2s/step - loss: 1.0119 - accuracy: 0.4892 - precision_6: 0.5982 - recall_6: 0.1707 - auc_6: 0.6828 - val_loss: 1.0627 - val_accuracy: 0.4388 - val_precision_6: 0.4627 - val_recall_6: 0.1582 - val_auc_6: 0.6094
# Epoch 10/30
# 25/25 [==============================] - 62s 2s/step - loss: 0.9800 - accuracy: 0.5197 - precision_6: 0.5666 - recall_6: 0.2115 - auc_6: 0.7064 - val_loss: 1.0628 - val_accuracy: 0.4286 - val_precision_6: 0.5119 - val_recall_6: 0.2194 - val_auc_6: 0.6168
# Epoch 11/30
# 25/25 [==============================] - 63s 3s/step - loss: 0.9669 - accuracy: 0.5287 - precision_6: 0.5759 - recall_6: 0.2561 - auc_6: 0.7132 - val_loss: 1.0568 - val_accuracy: 0.4082 - val_precision_6: 0.4688 - val_recall_6: 0.2296 - val_auc_6: 0.6204
# Epoch 12/30
# 25/25 [==============================] - 56s 2s/step - loss: 0.9527 - accuracy: 0.5401 - precision_6: 0.6107 - recall_6: 0.2917 - auc_6: 0.7266 - val_loss: 1.0735 - val_accuracy: 0.4235 - val_precision_6: 0.4865 - val_recall_6: 0.2755 - val_auc_6: 0.6201
# Epoch 13/30
# 25/25 [==============================] - 53s 2s/step - loss: 0.9385 - accuracy: 0.5478 - precision_6: 0.6174 - recall_6: 0.3350 - auc_6: 0.7354 - val_loss: 1.0339 - val_accuracy: 0.4643 - val_precision_6: 0.4783 - val_recall_6: 0.2245 - val_auc_6: 0.6485
# Epoch 14/30
# 25/25 [==============================] - 53s 2s/step - loss: 0.9371 - accuracy: 0.5350 - precision_6: 0.6070 - recall_6: 0.3325 - auc_6: 0.7369 - val_loss: 1.0283 - val_accuracy: 0.4490 - val_precision_6: 0.4947 - val_recall_6: 0.2398 - val_auc_6: 0.6478
# Epoch 15/30
# 25/25 [==============================] - 53s 2s/step - loss: 0.9349 - accuracy: 0.5669 - precision_6: 0.6072 - recall_6: 0.3427 - auc_6: 0.7397 - val_loss: 1.0267 - val_accuracy: 0.4745 - val_precision_6: 0.5208 - val_recall_6: 0.2551 - val_auc_6: 0.6508
# Epoch 16/30
# 25/25 [==============================] - 54s 2s/step - loss: 0.9262 - accuracy: 0.5541 - precision_6: 0.6117 - recall_6: 0.3592 - auc_6: 0.7446 - val_loss: 1.0130 - val_accuracy: 0.4796 - val_precision_6: 0.5106 - val_recall_6: 0.2449 - val_auc_6: 0.6637
# Epoch 17/30
# 25/25 [==============================] - 54s 2s/step - loss: 0.9174 - accuracy: 0.5656 - precision_6: 0.6545 - recall_6: 0.3669 - auc_6: 0.7514 - val_loss: 1.0377 - val_accuracy: 0.4490 - val_precision_6: 0.4960 - val_recall_6: 0.3163 - val_auc_6: 0.6499
# Epoch 18/30
# 25/25 [==============================] - 53s 2s/step - loss: 0.9129 - accuracy: 0.5631 - precision_6: 0.6328 - recall_6: 0.3885 - auc_6: 0.7525 - val_loss: 1.0638 - val_accuracy: 0.4643 - val_precision_6: 0.4820 - val_recall_6: 0.3418 - val_auc_6: 0.6459
# Epoch 19/30
# 25/25 [==============================] - 54s 2s/step - loss: 0.9053 - accuracy: 0.5720 - precision_6: 0.6350 - recall_6: 0.3834 - auc_6: 0.7579 - val_loss: 1.0571 - val_accuracy: 0.4541 - val_precision_6: 0.4863 - val_recall_6: 0.3622 - val_auc_6: 0.6523
# Epoch 20/30
# 25/25 [==============================] - 53s 2s/step - loss: 0.9006 - accuracy: 0.5694 - precision_6: 0.6426 - recall_6: 0.4076 - auc_6: 0.7622 - val_loss: 1.0386 - val_accuracy: 0.4439 - val_precision_6: 0.4928 - val_recall_6: 0.3469 - val_auc_6: 0.6650
# Epoch 21/30
# 25/25 [==============================] - 61s 2s/step - loss: 0.8945 - accuracy: 0.5720 - precision_6: 0.6267 - recall_6: 0.4127 - auc_6: 0.7638 - val_loss: 1.0110 - val_accuracy: 0.4694 - val_precision_6: 0.5299 - val_recall_6: 0.3163 - val_auc_6: 0.6682
# Epoch 22/30
# 25/25 [==============================] - 61s 2s/step - loss: 0.8963 - accuracy: 0.5936 - precision_6: 0.6512 - recall_6: 0.4115 - auc_6: 0.7652 - val_loss: 1.0039 - val_accuracy: 0.4898 - val_precision_6: 0.5410 - val_recall_6: 0.3367 - val_auc_6: 0.6769
# Epoch 23/30
# 25/25 [==============================] - 61s 2s/step - loss: 0.8900 - accuracy: 0.5732 - precision_6: 0.6404 - recall_6: 0.4038 - auc_6: 0.7690 - val_loss: 1.0369 - val_accuracy: 0.4490 - val_precision_6: 0.4789 - val_recall_6: 0.3469 - val_auc_6: 0.6681
# Epoch 24/30
# 25/25 [==============================] - 63s 2s/step - loss: 0.8685 - accuracy: 0.6051 - precision_6: 0.6737 - recall_6: 0.4497 - auc_6: 0.7815 - val_loss: 1.0231 - val_accuracy: 0.4847 - val_precision_6: 0.4964 - val_recall_6: 0.3520 - val_auc_6: 0.6771
# Epoch 25/30
# 25/25 [==============================] - 63s 2s/step - loss: 0.8861 - accuracy: 0.5860 - precision_6: 0.6523 - recall_6: 0.4229 - auc_6: 0.7704 - val_loss: 0.9793 - val_accuracy: 0.5102 - val_precision_6: 0.5913 - val_recall_6: 0.3469 - val_auc_6: 0.6961
# Epoch 26/30
# 25/25 [==============================] - 67s 3s/step - loss: 0.8613 - accuracy: 0.6076 - precision_6: 0.6667 - recall_6: 0.4459 - auc_6: 0.7869 - val_loss: 1.0477 - val_accuracy: 0.4643 - val_precision_6: 0.4933 - val_recall_6: 0.3776 - val_auc_6: 0.6699
# Epoch 27/30
# 25/25 [==============================] - 66s 3s/step - loss: 0.8824 - accuracy: 0.5885 - precision_6: 0.6437 - recall_6: 0.4395 - auc_6: 0.7743 - val_loss: 0.9848 - val_accuracy: 0.4898 - val_precision_6: 0.5478 - val_recall_6: 0.3214 - val_auc_6: 0.6860
# Epoch 28/30
# 25/25 [==============================] - 67s 3s/step - loss: 0.8619 - accuracy: 0.5962 - precision_6: 0.6704 - recall_6: 0.4561 - auc_6: 0.7851 - val_loss: 1.0483 - val_accuracy: 0.4796 - val_precision_6: 0.5130 - val_recall_6: 0.4031 - val_auc_6: 0.6717
# Epoch 29/30
# 25/25 [==============================] - 68s 3s/step - loss: 0.8582 - accuracy: 0.6013 - precision_6: 0.6642 - recall_6: 0.4662 - auc_6: 0.7873 - val_loss: 1.0054 - val_accuracy: 0.4796 - val_precision_6: 0.5854 - val_recall_6: 0.3673 - val_auc_6: 0.6840
# Epoch 30/30
# 25/25 [==============================] - 61s 2s/step - loss: 0.8450 - accuracy: 0.6089 - precision_6: 0.6956 - recall_6: 0.4803 - auc_6: 0.7955 - val_loss: 1.0292 - val_accuracy: 0.4898 - val_precision_6: 0.5163 - val_recall_6: 0.4031 - val_auc_6: 0.6835

# %%
import matplotlib.pyplot as plt

# Plot training history for loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Mark the best epoch for validation loss
best_epoch_loss = np.argmin(history.history['val_loss'])
plt.axvline(x=best_epoch_loss, color='r', linestyle='--', label=f'Best Epoch Loss: {best_epoch_loss}')
plt.legend()

# Plot training history for accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Mark the best epoch for validation accuracy
best_epoch_accuracy = np.argmax(history.history['val_accuracy'])
plt.axvline(x=best_epoch_accuracy, color='r', linestyle='--', label=f'Best Epoch Accuracy: {best_epoch_accuracy}')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Print the best epochs
print(f'Best Epoch for Validation Loss: {best_epoch_loss}')
print(f'Best Epoch for Validation Accuracy: {best_epoch_accuracy}')
# Out:
# Best Epoch for Validation Loss: 24
# Best Epoch for Validation Accuracy: 24

# %% [markdown]
# # Model Testing and Evaluation

# %%
# Load and test an image of curly hair
img_curly = keras.preprocessing.image.load_img(
    "hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--layered-natural-hair-natural-black-hairstyles.jpg", target_size=image_size
)
img_array_curly = keras.preprocessing.image.img_to_array(img_curly)
img_array_curly = tf.expand_dims(img_array_curly, 0)  # Create batch axis

predictions_curly = model.predict(img_array_curly)
print(
    "CURLY: This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions_curly[0])
)

# Load and test an image of straight hair
img_straight = keras.preprocessing.image.load_img(
    "hair_types/Straight_Hair/1-short-spiky-mens-haircut.jpg", target_size=image_size
)
img_array_straight = keras.preprocessing.image.img_to_array(img_straight)
img_array_straight = tf.expand_dims(img_array_straight, 0)  # Create batch axis

predictions_straight = model.predict(img_array_straight)
print(
    "STRAIGHT: This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions_straight[0])
)

# Load and test an image of wavy hair
img_wavy = keras.preprocessing.image.load_img(
    "hair_types/Wavy_Hair/2-Short-High-Volume-Hairstyle.jpg", target_size=image_size
)
img_array_wavy = keras.preprocessing.image.img_to_array(img_wavy)
img_array_wavy = tf.expand_dims(img_array_wavy, 0)  # Create batch axis

predictions_wavy = model.predict(img_array_wavy)
print(
    "WAVY: This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions_wavy[0])
)
# Out:
# 1/1 [==============================] - 0s 250ms/step
# CURLY: This image is 0.78 percent curly hair, 0.11 percent straight hair, and 0.11 percent wavy hair.
# 1/1 [==============================] - 0s 37ms/step
# STRAIGHT: This image is 0.00 percent curly hair, 0.76 percent straight hair, and 0.24 percent wavy hair.
# 1/1 [==============================] - 0s 44ms/step
# WAVY: This image is 0.38 percent curly hair, 0.08 percent straight hair, and 0.54 percent wavy hair.

# %% [markdown]
# 1ADDED: give you insights into how well your model generalizes to new, unseen data based on your validation dataset

# %% [markdown]
# AUC = 0.5: The model performs no better than random chance.
#
# AUC < 0.5: The model performs worse than random chance.
#
# AUC > 0.5: The model has some discriminatory power, with higher values indicating better discrimination.

# %%
val_loss, val_accuracy, val_precision, val_recall, val_auc = model.evaluate(val_ds)
print(f"Validation Loss: {val_loss}")
print(f"Validation Accuracy: {val_accuracy}")
print(f"Validation Precision: {val_precision}")
print(f"Validation Recall: {val_recall}")
print(f"Validation AUC: {val_auc}")
# Out:
# 7/7 [==============================] - 1s 97ms/step - loss: 1.0289 - accuracy: 0.4898 - precision_6: 0.5163 - recall_6: 0.4031 - auc_6: 0.6835
# Validation Loss: 1.0289381742477417
# Validation Accuracy: 0.4897959232330322
# Validation Precision: 0.516339898109436
# Validation Recall: 0.4030612111091614
# Validation AUC: 0.6834782361984253

# %%
val_images = []
val_labels = []

for (images, labels) in val_ds.take(3):  # Assuming your dataset does not include filenames
    val_images.append(images)
    val_labels.append(labels)

# Concatenate the batches to get the images and labels
val_images = tf.concat(val_images, axis=0)
val_labels = tf.concat(val_labels, axis=0)

# Test the model on the selected validation images
predictions = model.predict(val_images)

for i in range(len(val_images)):
    print(f"Image {i + 1}")
    print(f"True Label: {val_labels[i]}")
    print(f"Predictions: {predictions[i]}")
    print()
# Out:
# 3/3 [==============================] - 0s 63ms/step
# Image 1
# True Label: [0. 0. 1.]
# Predictions: [0.01492 0.518   0.4663 ]
#
# Image 2
# True Label: [0. 1. 0.]
# Predictions: [0.01129 0.521   0.4678 ]
#
# Image 3
# True Label: [0. 1. 0.]
# Predictions: [0.4802 0.234  0.2852]
#
# Image 4
# True Label: [0. 1. 0.]
# Predictions: [0.8027  0.117   0.08057]
#
# Image 5
# True Label: [1. 0. 0.]
# Predictions: [0.5356 0.2283 0.2366]
#
# Image 6
# True Label: [1. 0. 0.]
# Predictions: [0.8804  0.1041  0.01576]
#
# Image 7
# True Label: [0. 0. 1.]
# Predictions: [0.086  0.4104 0.5034]
#
# Image 8
# True Label: [1. 0. 0.]
# Predictions: [0.639  0.1626 0.1981]
#
# Image 9
# True Label: [1. 0. 0.]
# Predictions: [0.626  0.1438 0.2303]
#
# Image 10
# True Label: [0. 1. 0.]
# Predictions: [0.7373  0.1608  0.10254]
#
# Image 11
# True Label: [0. 0. 1.]
# Predictions: [0.08966 0.1243  0.7866 ]
#
# Image 12
# True Label: [0. 1. 0.]
# Predictions: [0.4731 0.2625 0.2644]
#
# Image 13
# True Label: [0. 1. 0.]
# Predictions: [0.04913 0.2443  0.7065 ]
#
# Image 14
# True Label: [1. 0. 0.]
# Predictions: [0.6655 0.1891 0.1455]
#
# Image 15
# True Label: [0. 1. 0.]
# Predictions: [0.2289 0.4177 0.354 ]
#
# Image 16
# True Label: [0. 1. 0.]
# Predictions: [0.641  0.1506 0.2078]
#
# Image 17
# True Label: [1. 0. 0.]
# Predictions: [0.5903 0.2103 0.1987]
#
# Image 18
# True Label: [0. 0. 1.]
# Predictions: [4.611e-04 6.470e-01 3.525e-01]
#
# Image 19
# True Label: [0. 0. 1.]
# Predictions: [0.009415 0.5625   0.4277  ]
#
# Image 20
# True Label: [0. 1. 0.]
# Predictions: [0.02692 0.4941  0.479  ]
#
# Image 21
# True Label: [0. 1. 0.]
# Predictions: [0.5625 0.2202 0.2175]
#
# Image 22
# True Label: [0. 0. 1.]
# Predictions: [0.301  0.1092 0.5894]
#
# Image 23
# True Label: [0. 1. 0.]
# Predictions: [0.663  0.1453 0.1919]
#
# Image 24
# True Label: [0. 0. 1.]
# Predictions: [0.002295 0.6025   0.395   ]
#
# Image 25
# True Label: [0. 0. 1.]
# Predictions: [0.1974 0.336  0.4663]
#
# Image 26
# True Label: [0. 0. 1.]
# Predictions: [0.009926 0.557    0.4333  ]
#
# Image 27
# True Label: [0. 1. 0.]
# Predictions: [0.528  0.2286 0.2433]
#
# Image 28
# True Label: [0. 0. 1.]
# Predictions: [0.4688 0.1669 0.3643]
#
# Image 29
# True Label: [0. 0. 1.]
# Predictions: [0.545   0.12006 0.335  ]
#
# Image 30
# True Label: [1. 0. 0.]
# Predictions: [0.559  0.2483 0.1923]
#
# Image 31
# True Label: [0. 1. 0.]
# Predictions: [0.5576 0.2222 0.2207]
#
# Image 32
# True Label: [1. 0. 0.]
# Predictions: [0.3735 0.2905 0.3364]
#
# Image 33
# True Label: [0. 0. 1.]
# Predictions: [0.616  0.2734 0.1108]
#
# Image 34
# True Label: [0. 1. 0.]
# Predictions: [0.02097 0.66    0.3184 ]
#
# Image 35
# True Label: [0. 1. 0.]
# Predictions: [0.4475 0.2566 0.2961]
#
# Image 36
# True Label: [0. 0. 1.]
# Predictions: [0.0313 0.3545 0.6143]
#
# Image 37
# True Label: [0. 0. 1.]
# Predictions: [0.2256 0.409  0.3652]
#
# Image 38
# True Label: [1. 0. 0.]
# Predictions: [0.692  0.1648 0.1436]
#
# Image 39
# True Label: [0. 1. 0.]
# Predictions: [0.3516 0.4238 0.2245]
#
# Image 40
# True Label: [0. 1. 0.]
# Predictions: [0.1393 0.4875 0.3738]
#
# Image 41
# True Label: [1. 0. 0.]
# Predictions: [0.2717  0.11646 0.612  ]
#
# Image 42
# True Label: [0. 1. 0.]
# Predictions: [0.5283 0.2352 0.2363]
#
# Image 43
# True Label: [1. 0. 0.]
# Predictions: [0.5913 0.2559 0.1528]
#
# Image 44
# True Label: [1. 0. 0.]
# Predictions: [0.53   0.1556 0.3145]
#
# Image 45
# True Label: [1. 0. 0.]
# Predictions: [0.8174 0.1019 0.0803]
#
# Image 46
# True Label: [1. 0. 0.]
# Predictions: [0.08997 0.549   0.361  ]
#
# Image 47
# True Label: [0. 1. 0.]
# Predictions: [0.548  0.2393 0.213 ]
#
# Image 48
# True Label: [0. 0. 1.]
# Predictions: [0.3271 0.4026 0.271 ]
#
# Image 49
# True Label: [1. 0. 0.]
# Predictions: [0.4253 0.1907 0.384 ]
#
# Image 50
# True Label: [0. 1. 0.]
# Predictions: [0.0278 0.4531 0.5186]
#
# Image 51
# True Label: [1. 0. 0.]
# Predictions: [0.645  0.1467 0.2084]
#
# Image 52
# True Label: [0. 1. 0.]
# Predictions: [0.0056 0.541  0.4526]
#
# Image 53
# True Label: [0. 1. 0.]
# Predictions: [0.649   0.2421  0.10876]
#
# Image 54
# True Label: [0. 0. 1.]
# Predictions: [0.768   0.1749  0.05673]
#
# Image 55
# True Label: [0. 1. 0.]
# Predictions: [0.144  0.5215 0.335 ]
#
# Image 56
# True Label: [1. 0. 0.]
# Predictions: [0.05942 0.2554  0.6855 ]
#
# Image 57
# True Label: [0. 0. 1.]
# Predictions: [0.02492 0.3015  0.674  ]
#
# Image 58
# True Label: [0. 1. 0.]
# Predictions: [2.687e-04 9.219e-01 7.819e-02]
#
# Image 59
# True Label: [1. 0. 0.]
# Predictions: [0.767  0.1181 0.1143]
#
# Image 60
# True Label: [0. 1. 0.]
# Predictions: [0.01093 0.5127  0.4768 ]
#
# Image 61
# True Label: [0. 0. 1.]
# Predictions: [0.5693 0.1763 0.2542]
#
# Image 62
# True Label: [0. 1. 0.]
# Predictions: [0.3892 0.4343 0.1761]
#
# Image 63
# True Label: [0. 0. 1.]
# Predictions: [0.3713 0.2722 0.357 ]
#
# Image 64
# True Label: [1. 0. 0.]
# Predictions: [0.311  0.4287 0.26  ]
#
# Image 65
# True Label: [0. 0. 1.]
# Predictions: [0.756   0.11847 0.1261 ]
#
# Image 66
# True Label: [0. 1. 0.]
# Predictions: [0.555  0.263  0.1823]
#
# Image 67
# True Label: [0. 0. 1.]
# Predictions: [0.5464 0.1814 0.2722]
#
# Image 68
# True Label: [0. 1. 0.]
# Predictions: [0.002266 0.77     0.2277  ]
#
# Image 69
# True Label: [0. 1. 0.]
# Predictions: [0.03244 0.287   0.68   ]
#
# Image 70
# True Label: [0. 1. 0.]
# Predictions: [0.6196 0.2028 0.1772]
#
# Image 71
# True Label: [0. 0. 1.]
# Predictions: [0.0948 0.5986 0.307 ]
#
# Image 72
# True Label: [0. 0. 1.]
# Predictions: [0.014656 0.6455   0.3394  ]
#
# Image 73
# True Label: [1. 0. 0.]
# Predictions: [0.1503 0.4844 0.3652]
#
# Image 74
# True Label: [0. 0. 1.]
# Predictions: [0.6196 0.1624 0.2183]
#
# Image 75
# True Label: [0. 1. 0.]
# Predictions: [0.003006 0.5864   0.4106  ]
#
# Image 76
# True Label: [1. 0. 0.]
# Predictions: [0.935   0.0344  0.03043]
#
# Image 77
# True Label: [0. 0. 1.]
# Predictions: [0.02464 0.1818  0.794  ]
#
# Image 78
# True Label: [0. 0. 1.]
# Predictions: [0.3167 0.2311 0.4524]
#
# Image 79
# True Label: [1. 0. 0.]
# Predictions: [0.4736 0.3362 0.1898]
#
# Image 80
# True Label: [0. 0. 1.]
# Predictions: [0.08636 0.2568  0.6567 ]
#
# Image 81
# True Label: [0. 0. 1.]
# Predictions: [0.1174 0.4167 0.4663]
#
# Image 82
# True Label: [0. 1. 0.]
# Predictions: [0.3037 0.3872 0.3086]
#
# Image 83
# True Label: [0. 1. 0.]
# Predictions: [0.04648 0.618   0.3347 ]
#
# Image 84
# True Label: [1. 0. 0.]
# Predictions: [0.577  0.2372 0.1852]
#
# Image 85
# True Label: [1. 0. 0.]
# Predictions: [0.0429 0.622  0.3345]
#
# Image 86
# True Label: [0. 1. 0.]
# Predictions: [0.02547 0.286   0.6885 ]
#
# Image 87
# True Label: [1. 0. 0.]
# Predictions: [0.5264 0.3267 0.1467]
#
# Image 88
# True Label: [1. 0. 0.]
# Predictions: [0.922   0.0519  0.02596]
#
# Image 89
# True Label: [0. 0. 1.]
# Predictions: [0.5737 0.261  0.1653]
#
# Image 90
# True Label: [0. 1. 0.]
# Predictions: [0.2277 0.1726 0.5996]
#
# Image 91
# True Label: [0. 1. 0.]
# Predictions: [0.08203 0.348   0.5703 ]
#
# Image 92
# True Label: [0. 1. 0.]
# Predictions: [0.671  0.2452 0.0839]
#
# Image 93
# True Label: [0. 0. 1.]
# Predictions: [0.2737 0.5513 0.1757]
#
# Image 94
# True Label: [0. 1. 0.]
# Predictions: [0.02992 0.27    0.6997 ]
#
# Image 95
# True Label: [1. 0. 0.]
# Predictions: [0.262  0.3198 0.418 ]
#
# Image 96
# True Label: [1. 0. 0.]
# Predictions: [0.851   0.0942  0.05505]
