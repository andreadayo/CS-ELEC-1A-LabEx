# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Preprocessing and Cleaning

# %%
from pathlib import Path
import imghdr
import os

data_dir = "hair_types"
image_extensions = [".png", ".jpg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]

for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        if filepath.exists():  # Check if the file exists before opening it
            img_type = imghdr.what(filepath)
            if img_type is None:
                print(f"{filepath} is not an image")
                os.remove(filepath)
            elif img_type not in img_type_accepted_by_tf:
                print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
                os.remove(filepath)
        else:
            print(f"{filepath} does not exist.")
# Out:
# hair_types\Straight_Hair\graphicstock-young-handsome-asiatic-long-brown-straight-hair-woman-taking-selfie-outdoor-in-the-city-with-a-smartphone-smiling-vanity-technology-social-network-concept_B6fyU2Ok-_SB_PM.jpg does not exist.
# hair_types\Straight_Hair\graphicstock-young-handsome-caucasian-reddish-straight-hair-woman-sitting-on-a-small-wall-holding-a-tablet-taking-a-selfie-doing-grimace-technology-social-network-youthful-concept_BTFpe2_1W_SB_PM.jpg does not exist.

# %% [markdown]
# # Data Loading and Splitting

# %% [markdown]
# 1ADDED: test_ds

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

image_size = (64, 64)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical'
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size, 
    labels='inferred',
    label_mode='categorical',
)
# Out:
# Found 981 files belonging to 3 classes.
# Using 785 files for training.
# Found 981 files belonging to 3 classes.
# Using 196 files for validation.

# %%
class_names = train_ds.class_names

# Count the number of samples per class in the training set
for class_name in class_names:
    num_samples = len([filename for filename in train_ds.file_paths if class_name in filename])
    print(f"Number of {class_name} samples in the training set: {num_samples}")

print()

# Count the number of samples per class in the validation set
for class_name in class_names:
    num_samples = len([filename for filename in val_ds.file_paths if class_name in filename])
    print(f"Number of {class_name} samples in the validation set: {num_samples}")
# Out:
# Number of Curly_Hair samples in the training set: 276
# Number of Straight_Hair samples in the training set: 250
# Number of Wavy_Hair samples in the training set: 259
#
# Number of Curly_Hair samples in the validation set: 56
# Number of Straight_Hair samples in the validation set: 68
# Number of Wavy_Hair samples in the validation set: 72

# %% [markdown]
# # Mixed Precision Training and Data Prefetching

# %% [markdown]
# 1ADDED: Mixed Precision Training -  speed up training without sacrificing much in terms of accuracy

# %%
#policy = tf.keras.mixed_precision.Policy('mixed_float16')
#tf.keras.mixed_precision.set_global_policy(policy)

# %% [markdown]
# 1ADDED: Use the prefetch transformation to overlap the preprocessing and model execution of training.

# %%
#AUTOTUNE = tf.data.experimental.AUTOTUNE
#train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Visualization of Training Data

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(np.argmax(labels[i])))
        plt.axis("off")
plt.show()

# %% [markdown]
# # Model Architecture

# %% [markdown]
# Adding max pooling layers helps reduce the spatial dimensions and control overfitting.

# %%
import tensorflow as tf
from tensorflow.keras import layers
from keras.models import Sequential

model = Sequential()
model.add(layers.Input(shape=image_size + (3,)))  # 64, 64, 3
model.add(layers.Rescaling(1.0 / 255))

model.add(layers.Conv2D(filters=8, kernel_size=3, strides=2, padding='same', dilation_rate=1))
model.add(layers.BatchNormalization())
model.add(layers.Activation("relu"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, kernel_size=3, strides=1, padding='same', dilation_rate=1))
model.add(layers.BatchNormalization())
model.add(layers.Activation("relu"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=1, padding='valid'))

model.add(layers.Conv2D(filters=32, kernel_size=3, strides=1, padding='same', dilation_rate=1))
model.add(layers.BatchNormalization())
model.add(layers.Activation("relu"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=1, padding='valid'))


model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(128))
model.add(layers.BatchNormalization())
model.add(layers.Activation("relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(3))
model.add(layers.Activation("softmax"))

# %% [markdown]
# # Visualizing Model Architecture

# %%
tf.keras.utils.plot_model(model, to_file='model_archi_06.png', show_shapes=True)

# %% [markdown]
# # Display Model Summary

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 64, 64, 3)         0
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 8)         224
#
#  batch_normalization_4 (Bat  (None, 32, 32, 8)         32
#  chNormalization)
#
#  activation_5 (Activation)   (None, 32, 32, 8)         0
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 8)         0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 16)        1168
#
#  batch_normalization_5 (Bat  (None, 16, 16, 16)        64
#  chNormalization)
#
#  activation_6 (Activation)   (None, 16, 16, 16)        0
#
#  max_pooling2d_4 (MaxPoolin  (None, 15, 15, 16)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 15, 15, 32)        4640
#
#  batch_normalization_6 (Bat  (None, 15, 15, 32)        128
#  chNormalization)
#
#  activation_7 (Activation)   (None, 15, 15, 32)        0
#
#  max_pooling2d_5 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  global_average_pooling2d_1  (None, 32)                0
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 128)               4224
#
#  batch_normalization_7 (Bat  (None, 128)               512
#  chNormalization)
#
#  activation_8 (Activation)   (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 3)                 387
#
#  activation_9 (Activation)   (None, 3)                 0
#
# =================================================================
# Total params: 11379 (44.45 KB)
# Trainable params: 11011 (43.01 KB)
# Non-trainable params: 368 (1.44 KB)
# _________________________________________________________________

# %% [markdown]
# # Model Training

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

epochs = 50

early_stopping = EarlyStopping(
    monitor='val_loss',  # Stop training when validation loss does not improve
    patience=5,           # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
)

custom_optimizer = Adam(learning_rate=0.0005)

model.compile(
    optimizer=custom_optimizer,
    loss="categorical_crossentropy",
    metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()],
)

# %% [markdown]
# # Training the Model

# %%
history = model.fit(train_ds, epochs=epochs, validation_data=val_ds, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 25/25 [==============================] - 6s 103ms/step - loss: 1.3782 - accuracy: 0.3962 - precision_1: 0.4179 - recall_1: 0.3146 - auc_1: 0.5632 - val_loss: 1.0974 - val_accuracy: 0.3469 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5231
# Epoch 2/50
# 25/25 [==============================] - 3s 88ms/step - loss: 1.2321 - accuracy: 0.4433 - precision_1: 0.4583 - recall_1: 0.3427 - auc_1: 0.6139 - val_loss: 1.0931 - val_accuracy: 0.3469 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5464
# Epoch 3/50
# 25/25 [==============================] - 3s 103ms/step - loss: 1.1415 - accuracy: 0.4573 - precision_1: 0.4931 - recall_1: 0.3631 - auc_1: 0.6456 - val_loss: 1.0966 - val_accuracy: 0.3418 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5498
# Epoch 4/50
# 25/25 [==============================] - 3s 98ms/step - loss: 1.0662 - accuracy: 0.5210 - precision_1: 0.5541 - recall_1: 0.4178 - auc_1: 0.6966 - val_loss: 1.0981 - val_accuracy: 0.3673 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5516
# Epoch 5/50
# 25/25 [==============================] - 3s 101ms/step - loss: 1.0752 - accuracy: 0.4854 - precision_1: 0.5335 - recall_1: 0.3860 - auc_1: 0.6834 - val_loss: 1.0976 - val_accuracy: 0.3571 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5682
# Epoch 6/50
# 25/25 [==============================] - 4s 118ms/step - loss: 1.0511 - accuracy: 0.4981 - precision_1: 0.5225 - recall_1: 0.4000 - auc_1: 0.6961 - val_loss: 1.0943 - val_accuracy: 0.3418 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5698
# Epoch 7/50
# 25/25 [==============================] - 4s 123ms/step - loss: 1.0015 - accuracy: 0.5656 - precision_1: 0.5967 - recall_1: 0.4675 - auc_1: 0.7331 - val_loss: 1.0927 - val_accuracy: 0.4235 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.6172
# Epoch 8/50
# 25/25 [==============================] - 4s 119ms/step - loss: 0.9547 - accuracy: 0.5516 - precision_1: 0.5940 - recall_1: 0.4510 - auc_1: 0.7447 - val_loss: 1.0854 - val_accuracy: 0.3571 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5915
# Epoch 9/50
# 25/25 [==============================] - 4s 127ms/step - loss: 0.9886 - accuracy: 0.5656 - precision_1: 0.5946 - recall_1: 0.4764 - auc_1: 0.7408 - val_loss: 1.0881 - val_accuracy: 0.3571 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.5821
# Epoch 10/50
# 25/25 [==============================] - 4s 124ms/step - loss: 0.9638 - accuracy: 0.5439 - precision_1: 0.5877 - recall_1: 0.4522 - auc_1: 0.7476 - val_loss: 1.0663 - val_accuracy: 0.3520 - val_precision_1: 0.4286 - val_recall_1: 0.0153 - val_auc_1: 0.5953
# Epoch 11/50
# 25/25 [==============================] - 5s 139ms/step - loss: 0.9007 - accuracy: 0.5758 - precision_1: 0.6233 - recall_1: 0.5121 - auc_1: 0.7750 - val_loss: 1.0831 - val_accuracy: 0.3776 - val_precision_1: 0.4000 - val_recall_1: 0.0204 - val_auc_1: 0.6030
# Epoch 12/50
# 25/25 [==============================] - 4s 129ms/step - loss: 0.8682 - accuracy: 0.6115 - precision_1: 0.6597 - recall_1: 0.5261 - auc_1: 0.7924 - val_loss: 1.0643 - val_accuracy: 0.3622 - val_precision_1: 0.5385 - val_recall_1: 0.0714 - val_auc_1: 0.6070
# Epoch 13/50
# 25/25 [==============================] - 4s 133ms/step - loss: 0.8348 - accuracy: 0.6178 - precision_1: 0.6603 - recall_1: 0.5299 - auc_1: 0.8059 - val_loss: 1.0964 - val_accuracy: 0.3980 - val_precision_1: 0.4828 - val_recall_1: 0.2143 - val_auc_1: 0.6216
# Epoch 14/50
# 25/25 [==============================] - 5s 139ms/step - loss: 0.8331 - accuracy: 0.6191 - precision_1: 0.6546 - recall_1: 0.5312 - auc_1: 0.8051 - val_loss: 1.0657 - val_accuracy: 0.4337 - val_precision_1: 0.4713 - val_recall_1: 0.2092 - val_auc_1: 0.6275
# Epoch 15/50
# 25/25 [==============================] - 5s 142ms/step - loss: 0.8358 - accuracy: 0.6255 - precision_1: 0.6780 - recall_1: 0.5605 - auc_1: 0.8109 - val_loss: 0.9952 - val_accuracy: 0.4592 - val_precision_1: 0.5714 - val_recall_1: 0.2449 - val_auc_1: 0.6788
# Epoch 16/50
# 25/25 [==============================] - 5s 134ms/step - loss: 0.7893 - accuracy: 0.6522 - precision_1: 0.6959 - recall_1: 0.5860 - auc_1: 0.8302 - val_loss: 1.0139 - val_accuracy: 0.5051 - val_precision_1: 0.5196 - val_recall_1: 0.2704 - val_auc_1: 0.6838
# Epoch 17/50
# 25/25 [==============================] - 4s 125ms/step - loss: 0.7671 - accuracy: 0.6510 - precision_1: 0.6900 - recall_1: 0.5643 - auc_1: 0.8333 - val_loss: 0.9909 - val_accuracy: 0.4745 - val_precision_1: 0.5714 - val_recall_1: 0.3265 - val_auc_1: 0.6898
# Epoch 18/50
# 25/25 [==============================] - 5s 159ms/step - loss: 0.7416 - accuracy: 0.6879 - precision_1: 0.7277 - recall_1: 0.6127 - auc_1: 0.8487 - val_loss: 0.9729 - val_accuracy: 0.4745 - val_precision_1: 0.5276 - val_recall_1: 0.3418 - val_auc_1: 0.7027
# Epoch 19/50
# 25/25 [==============================] - 6s 173ms/step - loss: 0.7677 - accuracy: 0.6573 - precision_1: 0.7037 - recall_1: 0.5809 - auc_1: 0.8373 - val_loss: 0.9876 - val_accuracy: 0.4796 - val_precision_1: 0.5540 - val_recall_1: 0.3929 - val_auc_1: 0.7010
# Epoch 20/50
# 25/25 [==============================] - 7s 185ms/step - loss: 0.7001 - accuracy: 0.6955 - precision_1: 0.7393 - recall_1: 0.6357 - auc_1: 0.8664 - val_loss: 0.9913 - val_accuracy: 0.4388 - val_precision_1: 0.4962 - val_recall_1: 0.3367 - val_auc_1: 0.6927
# Epoch 21/50
# 25/25 [==============================] - 6s 155ms/step - loss: 0.6973 - accuracy: 0.6854 - precision_1: 0.7329 - recall_1: 0.6153 - auc_1: 0.8640 - val_loss: 1.0427 - val_accuracy: 0.4592 - val_precision_1: 0.5098 - val_recall_1: 0.3980 - val_auc_1: 0.6904
# Epoch 22/50
# 25/25 [==============================] - 5s 160ms/step - loss: 0.6803 - accuracy: 0.6994 - precision_1: 0.7500 - recall_1: 0.6191 - auc_1: 0.8723 - val_loss: 0.9290 - val_accuracy: 0.5408 - val_precision_1: 0.5478 - val_recall_1: 0.4388 - val_auc_1: 0.7483
# Epoch 23/50
# 25/25 [==============================] - 6s 158ms/step - loss: 0.7118 - accuracy: 0.6917 - precision_1: 0.7263 - recall_1: 0.6153 - auc_1: 0.8583 - val_loss: 0.9712 - val_accuracy: 0.5255 - val_precision_1: 0.5769 - val_recall_1: 0.4592 - val_auc_1: 0.7221
# Epoch 24/50
# 25/25 [==============================] - 6s 167ms/step - loss: 0.6799 - accuracy: 0.7096 - precision_1: 0.7541 - recall_1: 0.6408 - auc_1: 0.8728 - val_loss: 1.2370 - val_accuracy: 0.4286 - val_precision_1: 0.4198 - val_recall_1: 0.3469 - val_auc_1: 0.6325
# Epoch 25/50
# 25/25 [==============================] - 6s 168ms/step - loss: 0.6642 - accuracy: 0.7312 - precision_1: 0.7744 - recall_1: 0.6777 - auc_1: 0.8813 - val_loss: 1.0528 - val_accuracy: 0.4796 - val_precision_1: 0.5000 - val_recall_1: 0.3929 - val_auc_1: 0.6962
# Epoch 26/50
# 25/25 [==============================] - 5s 148ms/step - loss: 0.6158 - accuracy: 0.7338 - precision_1: 0.7814 - recall_1: 0.6739 - auc_1: 0.8980 - val_loss: 0.9586 - val_accuracy: 0.5408 - val_precision_1: 0.5595 - val_recall_1: 0.4796 - val_auc_1: 0.7448
# Epoch 27/50
# 25/25 [==============================] - 8s 222ms/step - loss: 0.6512 - accuracy: 0.7389 - precision_1: 0.7804 - recall_1: 0.6790 - auc_1: 0.8852 - val_loss: 0.9656 - val_accuracy: 0.5051 - val_precision_1: 0.5548 - val_recall_1: 0.4388 - val_auc_1: 0.7397

# %%
import matplotlib.pyplot as plt

# Plot training history for loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Mark the best epoch for validation loss
best_epoch_loss = np.argmin(history.history['val_loss'])
plt.axvline(x=best_epoch_loss, color='r', linestyle='--', label=f'Best Epoch Loss: {best_epoch_loss}')
plt.legend()

# Plot training history for accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Mark the best epoch for validation accuracy
best_epoch_accuracy = np.argmax(history.history['val_accuracy'])
plt.axvline(x=best_epoch_accuracy, color='r', linestyle='--', label=f'Best Epoch Accuracy: {best_epoch_accuracy}')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Print the best epochs
print(f'Best Epoch for Validation Loss: {best_epoch_loss}')
print(f'Best Epoch for Validation Accuracy: {best_epoch_accuracy}')
# Out:
# Best Epoch for Validation Loss: 21
# Best Epoch for Validation Accuracy: 21

# %% [markdown]
# # Model Testing and Evaluation

# %%
# Load and test an image of curly hair
img_curly = keras.preprocessing.image.load_img(
    "hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--layered-natural-hair-natural-black-hairstyles.jpg", target_size=image_size
)
img_array_curly = keras.preprocessing.image.img_to_array(img_curly)
img_array_curly = tf.expand_dims(img_array_curly, 0)  # Create batch axis

predictions_curly = model.predict(img_array_curly)
print(
    "CURLY: This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions_curly[0])
)

# Load and test an image of straight hair
img_straight = keras.preprocessing.image.load_img(
    "hair_types/Straight_Hair/1-short-spiky-mens-haircut.jpg", target_size=image_size
)
img_array_straight = keras.preprocessing.image.img_to_array(img_straight)
img_array_straight = tf.expand_dims(img_array_straight, 0)  # Create batch axis

predictions_straight = model.predict(img_array_straight)
print(
    "STRAIGHT: This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions_straight[0])
)

# Load and test an image of wavy hair
img_wavy = keras.preprocessing.image.load_img(
    "hair_types/Wavy_Hair/2-Short-High-Volume-Hairstyle.jpg", target_size=image_size
)
img_array_wavy = keras.preprocessing.image.img_to_array(img_wavy)
img_array_wavy = tf.expand_dims(img_array_wavy, 0)  # Create batch axis

predictions_wavy = model.predict(img_array_wavy)
print(
    "WAVY: This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions_wavy[0])
)
# Out:
# 1/1 [==============================] - 0s 435ms/step
# CURLY: This image is 0.99 percent curly hair, 0.01 percent straight hair, and 0.00 percent wavy hair.
# 1/1 [==============================] - 0s 55ms/step
# STRAIGHT: This image is 0.06 percent curly hair, 0.71 percent straight hair, and 0.23 percent wavy hair.
# 1/1 [==============================] - 0s 87ms/step
# WAVY: This image is 0.12 percent curly hair, 0.23 percent straight hair, and 0.65 percent wavy hair.

# %% [markdown]
# 1ADDED: give you insights into how well your model generalizes to new, unseen data based on your validation dataset

# %% [markdown]
# AUC = 0.5: The model performs no better than random chance.
#
# AUC < 0.5: The model performs worse than random chance.
#
# AUC > 0.5: The model has some discriminatory power, with higher values indicating better discrimination.

# %%
val_loss, val_accuracy, val_precision, val_recall, val_auc = model.evaluate(val_ds)
print(f"Validation Accuracy: {val_accuracy}")
print(f"Validation Precision: {val_precision}")
print(f"Validation Recall: {val_recall}")
print(f"Validation AUC: {val_auc}")
# Out:
# 7/7 [==============================] - 1s 35ms/step - loss: 0.9290 - accuracy: 0.5408 - precision_1: 0.5478 - recall_1: 0.4388 - auc_1: 0.7483
# Validation Accuracy: 0.5408163070678711
# Validation Precision: 0.5477706789970398
# Validation Recall: 0.43877550959587097
# Validation AUC: 0.7483274936676025

# %%
import tensorflow as tf
from tensorflow import keras

# Assuming val_ds is your validation dataset
val_images = []
val_labels = []

for images, labels in val_ds.take(3):  # Take 3 batches (adjust as needed)
    val_images.append(images)
    val_labels.append(labels)

# Concatenate the batches to get the images and labels
val_images = tf.concat(val_images, axis=0)
val_labels = tf.concat(val_labels, axis=0)

# Test the model on the selected validation images
predictions = model.predict(val_images)

for i in range(len(val_images)):
    print(f"Image {i + 1}")
    print(f"True Label: {val_labels[i]}")
    print(f"Predictions: {predictions[i]}")
    print()
# Out:
# 3/3 [==============================] - 0s 35ms/step
# Image 1
# True Label: [0. 0. 1.]
# Predictions: [0.02717673 0.39466763 0.5781557 ]
#
# Image 2
# True Label: [0. 1. 0.]
# Predictions: [0.29283488 0.55357987 0.15358526]
#
# Image 3
# True Label: [0. 1. 0.]
# Predictions: [0.04330363 0.7325289  0.22416736]
#
# Image 4
# True Label: [0. 1. 0.]
# Predictions: [0.06681083 0.57575    0.35743922]
#
# Image 5
# True Label: [0. 0. 1.]
# Predictions: [0.19888532 0.42258197 0.37853268]
#
# Image 6
# True Label: [0. 0. 1.]
# Predictions: [0.2221397 0.0929651 0.6848952]
#
# Image 7
# True Label: [1. 0. 0.]
# Predictions: [0.23665161 0.19453707 0.5688113 ]
#
# Image 8
# True Label: [1. 0. 0.]
# Predictions: [0.6182109  0.22634092 0.15544823]
#
# Image 9
# True Label: [1. 0. 0.]
# Predictions: [0.5403266 0.0790529 0.3806205]
#
# Image 10
# True Label: [0. 1. 0.]
# Predictions: [0.8022977  0.12232853 0.07537376]
#
# Image 11
# True Label: [0. 0. 1.]
# Predictions: [0.00887883 0.5310371  0.46008402]
#
# Image 12
# True Label: [0. 0. 1.]
# Predictions: [0.05463173 0.3705966  0.57477164]
#
# Image 13
# True Label: [0. 1. 0.]
# Predictions: [0.05735459 0.7102056  0.23243973]
#
# Image 14
# True Label: [0. 0. 1.]
# Predictions: [0.3139207 0.2879321 0.3981472]
#
# Image 15
# True Label: [1. 0. 0.]
# Predictions: [0.8672599  0.09627233 0.03646778]
#
# Image 16
# True Label: [0. 1. 0.]
# Predictions: [0.10094692 0.40790424 0.49114883]
#
# Image 17
# True Label: [1. 0. 0.]
# Predictions: [0.51566637 0.29298836 0.1913453 ]
#
# Image 18
# True Label: [1. 0. 0.]
# Predictions: [0.8970511  0.03238759 0.07056134]
#
# Image 19
# True Label: [0. 0. 1.]
# Predictions: [0.04991446 0.23466589 0.7154197 ]
#
# Image 20
# True Label: [1. 0. 0.]
# Predictions: [0.4609993  0.27867952 0.2603212 ]
#
# Image 21
# True Label: [1. 0. 0.]
# Predictions: [0.6911771  0.13294923 0.17587362]
#
# Image 22
# True Label: [1. 0. 0.]
# Predictions: [0.5434256  0.12057712 0.33599728]
#
# Image 23
# True Label: [0. 0. 1.]
# Predictions: [0.27423134 0.14882101 0.57694757]
#
# Image 24
# True Label: [0. 1. 0.]
# Predictions: [0.04417545 0.74658424 0.20924026]
#
# Image 25
# True Label: [0. 1. 0.]
# Predictions: [0.04933511 0.38638213 0.56428283]
#
# Image 26
# True Label: [0. 1. 0.]
# Predictions: [0.13577299 0.25450447 0.60972255]
#
# Image 27
# True Label: [1. 0. 0.]
# Predictions: [0.9319117  0.00930486 0.0587834 ]
#
# Image 28
# True Label: [0. 0. 1.]
# Predictions: [0.04003394 0.30641907 0.65354705]
#
# Image 29
# True Label: [0. 0. 1.]
# Predictions: [0.11803181 0.23864116 0.643327  ]
#
# Image 30
# True Label: [0. 0. 1.]
# Predictions: [0.02778558 0.20890154 0.7633129 ]
#
# Image 31
# True Label: [0. 1. 0.]
# Predictions: [0.13848116 0.60903233 0.2524865 ]
#
# Image 32
# True Label: [1. 0. 0.]
# Predictions: [0.3704124  0.09987622 0.52971137]
#
# Image 33
# True Label: [0. 1. 0.]
# Predictions: [0.22841042 0.2711985  0.50039107]
#
# Image 34
# True Label: [1. 0. 0.]
# Predictions: [0.84733874 0.07082454 0.08183671]
#
# Image 35
# True Label: [0. 0. 1.]
# Predictions: [0.11786065 0.21339957 0.66873974]
#
# Image 36
# True Label: [0. 1. 0.]
# Predictions: [0.04709914 0.6094128  0.34348804]
#
# Image 37
# True Label: [0. 0. 1.]
# Predictions: [0.12560724 0.23344754 0.64094526]
#
# Image 38
# True Label: [0. 1. 0.]
# Predictions: [0.09098275 0.395787   0.5132302 ]
#
# Image 39
# True Label: [1. 0. 0.]
# Predictions: [0.91006124 0.06164967 0.02828909]
#
# Image 40
# True Label: [1. 0. 0.]
# Predictions: [0.85678494 0.01417297 0.12904206]
#
# Image 41
# True Label: [0. 0. 1.]
# Predictions: [0.14673473 0.46946704 0.3837982 ]
#
# Image 42
# True Label: [1. 0. 0.]
# Predictions: [0.01217816 0.38613752 0.60168433]
#
# Image 43
# True Label: [1. 0. 0.]
# Predictions: [0.41346774 0.5145697  0.07196252]
#
# Image 44
# True Label: [0. 1. 0.]
# Predictions: [0.12788995 0.36896056 0.5031495 ]
#
# Image 45
# True Label: [0. 1. 0.]
# Predictions: [0.06830895 0.4006663  0.53102475]
#
# Image 46
# True Label: [0. 1. 0.]
# Predictions: [0.0049229  0.8554986  0.13957843]
#
# Image 47
# True Label: [0. 0. 1.]
# Predictions: [0.7266078  0.09833569 0.17505647]
#
# Image 48
# True Label: [0. 1. 0.]
# Predictions: [0.00541556 0.25287116 0.7417133 ]
#
# Image 49
# True Label: [0. 1. 0.]
# Predictions: [0.4179184  0.28417417 0.29790738]
#
# Image 50
# True Label: [0. 0. 1.]
# Predictions: [0.2000242  0.22068797 0.57928777]
#
# Image 51
# True Label: [0. 0. 1.]
# Predictions: [0.25585595 0.43446827 0.3096758 ]
#
# Image 52
# True Label: [0. 0. 1.]
# Predictions: [0.5559075  0.08498096 0.35911164]
#
# Image 53
# True Label: [0. 0. 1.]
# Predictions: [0.25332662 0.28010297 0.46657038]
#
# Image 54
# True Label: [0. 1. 0.]
# Predictions: [0.7310786  0.12313631 0.14578502]
#
# Image 55
# True Label: [0. 0. 1.]
# Predictions: [0.23722342 0.47461122 0.28816536]
#
# Image 56
# True Label: [0. 1. 0.]
# Predictions: [0.02058589 0.15908098 0.82033306]
#
# Image 57
# True Label: [0. 0. 1.]
# Predictions: [0.11794607 0.2043091  0.67774487]
#
# Image 58
# True Label: [0. 1. 0.]
# Predictions: [0.03133087 0.14822865 0.8204404 ]
#
# Image 59
# True Label: [0. 1. 0.]
# Predictions: [0.0052019  0.20756586 0.7872322 ]
#
# Image 60
# True Label: [0. 0. 1.]
# Predictions: [0.13133715 0.11342734 0.75523555]
#
# Image 61
# True Label: [1. 0. 0.]
# Predictions: [0.22838865 0.31701273 0.45459867]
#
# Image 62
# True Label: [0. 1. 0.]
# Predictions: [0.05369492 0.21143393 0.73487115]
#
# Image 63
# True Label: [0. 0. 1.]
# Predictions: [0.94410384 0.0300178  0.02587831]
#
# Image 64
# True Label: [1. 0. 0.]
# Predictions: [0.7563707  0.190613   0.05301636]
#
# Image 65
# True Label: [1. 0. 0.]
# Predictions: [0.92145383 0.03544341 0.0431027 ]
#
# Image 66
# True Label: [0. 1. 0.]
# Predictions: [0.00912218 0.40180555 0.5890723 ]
#
# Image 67
# True Label: [1. 0. 0.]
# Predictions: [0.12257259 0.42188442 0.45554298]
#
# Image 68
# True Label: [0. 0. 1.]
# Predictions: [0.20041041 0.34223017 0.4573594 ]
#
# Image 69
# True Label: [0. 1. 0.]
# Predictions: [0.00871228 0.38349152 0.60779625]
#
# Image 70
# True Label: [0. 0. 1.]
# Predictions: [0.6378378  0.11279223 0.2493699 ]
#
# Image 71
# True Label: [1. 0. 0.]
# Predictions: [0.50063735 0.24484359 0.25451908]
#
# Image 72
# True Label: [1. 0. 0.]
# Predictions: [0.78164554 0.06148221 0.15687232]
#
# Image 73
# True Label: [1. 0. 0.]
# Predictions: [0.4875423  0.26484638 0.24761128]
#
# Image 74
# True Label: [0. 1. 0.]
# Predictions: [0.06519625 0.40395114 0.5308527 ]
#
# Image 75
# True Label: [0. 0. 1.]
# Predictions: [0.672698   0.14800522 0.17929678]
#
# Image 76
# True Label: [1. 0. 0.]
# Predictions: [0.68265665 0.14668632 0.17065696]
#
# Image 77
# True Label: [0. 0. 1.]
# Predictions: [0.03670703 0.20989695 0.75339603]
#
# Image 78
# True Label: [0. 1. 0.]
# Predictions: [0.15268026 0.25390866 0.5934111 ]
#
# Image 79
# True Label: [0. 1. 0.]
# Predictions: [0.00696576 0.5846008  0.4084334 ]
#
# Image 80
# True Label: [1. 0. 0.]
# Predictions: [0.34647194 0.03857999 0.6149481 ]
#
# Image 81
# True Label: [0. 0. 1.]
# Predictions: [0.53997415 0.21327232 0.24675351]
#
# Image 82
# True Label: [0. 1. 0.]
# Predictions: [0.00218936 0.23999569 0.75781494]
#
# Image 83
# True Label: [0. 1. 0.]
# Predictions: [0.13313276 0.5117808  0.3550865 ]
#
# Image 84
# True Label: [0. 1. 0.]
# Predictions: [0.51020217 0.26606128 0.22373663]
#
# Image 85
# True Label: [0. 0. 1.]
# Predictions: [0.629248   0.24621995 0.12453205]
#
# Image 86
# True Label: [1. 0. 0.]
# Predictions: [0.86626786 0.09599786 0.03773429]
#
# Image 87
# True Label: [1. 0. 0.]
# Predictions: [0.9227224  0.04064722 0.03663037]
#
# Image 88
# True Label: [0. 0. 1.]
# Predictions: [0.42862877 0.30826983 0.2631014 ]
#
# Image 89
# True Label: [0. 1. 0.]
# Predictions: [0.6829223  0.24185827 0.07521936]
#
# Image 90
# True Label: [0. 1. 0.]
# Predictions: [0.5162238  0.15344548 0.33033076]
#
# Image 91
# True Label: [0. 0. 1.]
# Predictions: [0.20365553 0.39814717 0.39819723]
#
# Image 92
# True Label: [0. 1. 0.]
# Predictions: [0.78251153 0.09032694 0.12716149]
#
# Image 93
# True Label: [0. 0. 1.]
# Predictions: [0.0984133  0.14417668 0.75741   ]
#
# Image 94
# True Label: [0. 1. 0.]
# Predictions: [0.9057469  0.05567935 0.03857384]
#
# Image 95
# True Label: [0. 0. 1.]
# Predictions: [0.65645397 0.0633402  0.28020588]
#
# Image 96
# True Label: [1. 0. 0.]
# Predictions: [0.9264561  0.04081736 0.0327265 ]
