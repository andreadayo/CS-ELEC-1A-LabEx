# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Preprocessing and Cleaning

# %%
from pathlib import Path
import imghdr
import os

data_dir = "hair_types"
image_extensions = [".png", ".jpg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]

for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        if filepath.exists():  # Check if the file exists before opening it
            img_type = imghdr.what(filepath)
            if img_type is None:
                print(f"{filepath} is not an image")
                os.remove(filepath)
            elif img_type not in img_type_accepted_by_tf:
                print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
                os.remove(filepath)
        else:
            print(f"{filepath} does not exist.")
# Out:
# hair_types\Straight_Hair\graphicstock-young-handsome-asiatic-long-brown-straight-hair-woman-taking-selfie-outdoor-in-the-city-with-a-smartphone-smiling-vanity-technology-social-network-concept_B6fyU2Ok-_SB_PM.jpg does not exist.
# hair_types\Straight_Hair\graphicstock-young-handsome-caucasian-reddish-straight-hair-woman-sitting-on-a-small-wall-holding-a-tablet-taking-a-selfie-doing-grimace-technology-social-network-youthful-concept_BTFpe2_1W_SB_PM.jpg does not exist.

# %% [markdown]
# # Data Loading and Splitting

# %% [markdown]
# 1ADDED: test_ds

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

image_size = (64, 64)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical'
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size, 
    labels='inferred',
    label_mode='categorical',
)
# Out:
# Found 981 files belonging to 3 classes.
# Using 785 files for training.
# Found 981 files belonging to 3 classes.
# Using 196 files for validation.

# %%
class_names = train_ds.class_names

# Count the number of samples per class in the training set
for class_name in class_names:
    num_samples = len([filename for filename in train_ds.file_paths if class_name in filename])
    print(f"Number of {class_name} samples in the training set: {num_samples}")

print()

# Count the number of samples per class in the validation set
for class_name in class_names:
    num_samples = len([filename for filename in val_ds.file_paths if class_name in filename])
    print(f"Number of {class_name} samples in the validation set: {num_samples}")
# Out:
# Number of Curly_Hair samples in the training set: 276
# Number of Straight_Hair samples in the training set: 250
# Number of Wavy_Hair samples in the training set: 259
#
# Number of Curly_Hair samples in the validation set: 56
# Number of Straight_Hair samples in the validation set: 68
# Number of Wavy_Hair samples in the validation set: 72

# %% [markdown]
# # Mixed Precision Training and Data Prefetching

# %% [markdown]
# 1ADDED: Mixed Precision Training -  speed up training without sacrificing much in terms of accuracy

# %%
policy = tf.keras.mixed_precision.Policy('mixed_float16')
tf.keras.mixed_precision.set_global_policy(policy)

# %% [markdown]
# 1ADDED: Use the prefetch transformation to overlap the preprocessing and model execution of training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Visualization of Training Data

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(np.argmax(labels[i])))
        plt.axis("off")
plt.show()

# %% [markdown]
# # Model Architecture

# %% [markdown]
# Adding max pooling layers helps reduce the spatial dimensions and control overfitting.

# %%
import tensorflow as tf
from tensorflow.keras import layers
from keras.models import Sequential

model = Sequential()
model.add(layers.Input(shape=image_size + (3,)))  # 64, 64, 3
model.add(layers.Rescaling(1.0 / 255))

model.add(layers.Conv2D(filters=8, kernel_size=3, strides=1, padding='same', dilation_rate=2))
model.add(layers.Activation("relu"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid'))

model.add(layers.Conv2D(filters=16, kernel_size=3, strides=1, padding='same', dilation_rate=2))
model.add(layers.Activation("relu"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid'))

model.add(layers.Conv2D(filters=32, kernel_size=3, strides=1, padding='same', dilation_rate=2))
model.add(layers.Activation("relu"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid'))

# added one more layer
model.add(layers.Conv2D(filters=64, kernel_size=3, strides=1, padding='same', dilation_rate=2))
model.add(layers.Activation("relu"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid'))

model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(64))
model.add(layers.Activation("relu"))
model.add(layers.Dense(3))
model.add(layers.Activation("softmax"))

# %% [markdown]
# # Visualizing Model Architecture

# %%
tf.keras.utils.plot_model(model, to_file='model_archi_04.png', show_shapes=True)

# %% [markdown]
# # Display Model Summary

# %%
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_10 (Rescaling)    (None, 64, 64, 3)         0
#
#  conv2d_19 (Conv2D)          (None, 64, 64, 8)         224
#
#  activation_18 (Activation)  (None, 64, 64, 8)         0
#
#  max_pooling2d_12 (MaxPooli  (None, 32, 32, 8)         0
#  ng2D)
#
#  conv2d_20 (Conv2D)          (None, 32, 32, 16)        1168
#
#  activation_19 (Activation)  (None, 32, 32, 16)        0
#
#  max_pooling2d_13 (MaxPooli  (None, 16, 16, 16)        0
#  ng2D)
#
#  conv2d_21 (Conv2D)          (None, 16, 16, 32)        4640
#
#  activation_20 (Activation)  (None, 16, 16, 32)        0
#
#  max_pooling2d_14 (MaxPooli  (None, 8, 8, 32)          0
#  ng2D)
#
#  conv2d_22 (Conv2D)          (None, 8, 8, 64)          18496
#
#  activation_21 (Activation)  (None, 8, 8, 64)          0
#
#  max_pooling2d_15 (MaxPooli  (None, 4, 4, 64)          0
#  ng2D)
#
#  global_average_pooling2d_3  (None, 64)                0
#   (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  activation_22 (Activation)  (None, 64)                0
#
#  dense_7 (Dense)             (None, 3)                 195
#
#  activation_23 (Activation)  (None, 3)                 0
#
# =================================================================
# Total params: 28883 (112.82 KB)
# Trainable params: 28883 (112.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Model Training

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

epochs = 50

early_stopping = EarlyStopping(
    monitor='val_loss',  # Stop training when validation loss does not improve
    patience=8,           # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
)

custom_optimizer = Adam(learning_rate=0.0001)

model.compile(
    optimizer=custom_optimizer,
    loss="categorical_crossentropy",
    metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()],
)

# %% [markdown]
# # Training the Model

# %%
history = model.fit(train_ds, epochs=epochs, validation_data=val_ds, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 25/25 [==============================] - 88s 3s/step - loss: 1.0984 - accuracy: 0.3516 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - auc_2: 0.5158 - val_loss: 1.1014 - val_accuracy: 0.2857 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.4893
# Epoch 2/50
# 25/25 [==============================] - 100s 4s/step - loss: 1.0968 - accuracy: 0.3516 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - auc_2: 0.5292 - val_loss: 1.1028 - val_accuracy: 0.2857 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5016
# Epoch 3/50
# 25/25 [==============================] - 104s 4s/step - loss: 1.0955 - accuracy: 0.3516 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - auc_2: 0.5458 - val_loss: 1.1015 - val_accuracy: 0.2857 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5017
# Epoch 4/50
# 25/25 [==============================] - 99s 4s/step - loss: 1.0947 - accuracy: 0.3516 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - auc_2: 0.5637 - val_loss: 1.1010 - val_accuracy: 0.2857 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5160
# Epoch 5/50
# 25/25 [==============================] - 99s 4s/step - loss: 1.0929 - accuracy: 0.3516 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - auc_2: 0.5812 - val_loss: 1.1009 - val_accuracy: 0.2857 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5344
# Epoch 6/50
# 25/25 [==============================] - 89s 4s/step - loss: 1.0909 - accuracy: 0.3516 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - auc_2: 0.5968 - val_loss: 1.0976 - val_accuracy: 0.2857 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5443
# Epoch 7/50
# 25/25 [==============================] - 93s 4s/step - loss: 1.0882 - accuracy: 0.3516 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - auc_2: 0.5998 - val_loss: 1.0981 - val_accuracy: 0.2857 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5430
# Epoch 8/50
# 25/25 [==============================] - 83s 3s/step - loss: 1.0864 - accuracy: 0.3580 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - auc_2: 0.5906 - val_loss: 1.0947 - val_accuracy: 0.2857 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5534
# Epoch 9/50
# 25/25 [==============================] - 82s 3s/step - loss: 1.0819 - accuracy: 0.3605 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - auc_2: 0.6034 - val_loss: 1.0875 - val_accuracy: 0.3010 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5582
# Epoch 10/50
# 25/25 [==============================] - 95s 4s/step - loss: 1.0755 - accuracy: 0.3860 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - auc_2: 0.6255 - val_loss: 1.0840 - val_accuracy: 0.3010 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.5638
# Epoch 11/50
# 25/25 [==============================] - 80s 3s/step - loss: 1.0716 - accuracy: 0.3962 - precision_2: 0.5000 - recall_2: 0.0025 - auc_2: 0.6086 - val_loss: 1.0744 - val_accuracy: 0.3980 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.6310
# Epoch 12/50
# 25/25 [==============================] - 85s 3s/step - loss: 1.0620 - accuracy: 0.4433 - precision_2: 0.8000 - recall_2: 0.0051 - auc_2: 0.6518 - val_loss: 1.0692 - val_accuracy: 0.3622 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_2: 0.6162
# Epoch 13/50
# 25/25 [==============================] - 86s 3s/step - loss: 1.0518 - accuracy: 0.4586 - precision_2: 0.6667 - recall_2: 0.0178 - auc_2: 0.6668 - val_loss: 1.0552 - val_accuracy: 0.4796 - val_precision_2: 1.0000 - val_recall_2: 0.0102 - val_auc_2: 0.6711
# Epoch 14/50
# 25/25 [==============================] - 72s 3s/step - loss: 1.0410 - accuracy: 0.4968 - precision_2: 0.6786 - recall_2: 0.0242 - auc_2: 0.6925 - val_loss: 1.0476 - val_accuracy: 0.4031 - val_precision_2: 0.9167 - val_recall_2: 0.0561 - val_auc_2: 0.6462
# Epoch 15/50
# 25/25 [==============================] - 62s 2s/step - loss: 1.0312 - accuracy: 0.4662 - precision_2: 0.6744 - recall_2: 0.0739 - auc_2: 0.6812 - val_loss: 1.0363 - val_accuracy: 0.4388 - val_precision_2: 0.8095 - val_recall_2: 0.0867 - val_auc_2: 0.6569
# Epoch 16/50
# 25/25 [==============================] - 71s 3s/step - loss: 1.0180 - accuracy: 0.5083 - precision_2: 0.7159 - recall_2: 0.0803 - auc_2: 0.7030 - val_loss: 1.0204 - val_accuracy: 0.4745 - val_precision_2: 0.8261 - val_recall_2: 0.0969 - val_auc_2: 0.6831
# Epoch 17/50
# 25/25 [==============================] - 76s 3s/step - loss: 1.0058 - accuracy: 0.5223 - precision_2: 0.6884 - recall_2: 0.1210 - auc_2: 0.7073 - val_loss: 1.0088 - val_accuracy: 0.4745 - val_precision_2: 0.7500 - val_recall_2: 0.1224 - val_auc_2: 0.6896
# Epoch 18/50
# 25/25 [==============================] - 113s 5s/step - loss: 0.9991 - accuracy: 0.5197 - precision_2: 0.7099 - recall_2: 0.1185 - auc_2: 0.7075 - val_loss: 1.0002 - val_accuracy: 0.4745 - val_precision_2: 0.6842 - val_recall_2: 0.1327 - val_auc_2: 0.6945
# Epoch 19/50
# 25/25 [==============================] - 127s 5s/step - loss: 0.9900 - accuracy: 0.4815 - precision_2: 0.6988 - recall_2: 0.1478 - auc_2: 0.7067 - val_loss: 1.0059 - val_accuracy: 0.4541 - val_precision_2: 0.6207 - val_recall_2: 0.1837 - val_auc_2: 0.6745
# Epoch 20/50
# 25/25 [==============================] - 101s 4s/step - loss: 0.9806 - accuracy: 0.5121 - precision_2: 0.6872 - recall_2: 0.1567 - auc_2: 0.7144 - val_loss: 0.9909 - val_accuracy: 0.4643 - val_precision_2: 0.6154 - val_recall_2: 0.1633 - val_auc_2: 0.6923
# Epoch 21/50
# 25/25 [==============================] - 110s 4s/step - loss: 0.9757 - accuracy: 0.5389 - precision_2: 0.6769 - recall_2: 0.1682 - auc_2: 0.7159 - val_loss: 0.9671 - val_accuracy: 0.5051 - val_precision_2: 0.6944 - val_recall_2: 0.1276 - val_auc_2: 0.7230
# Epoch 22/50
# 25/25 [==============================] - 107s 4s/step - loss: 0.9687 - accuracy: 0.5032 - precision_2: 0.6942 - recall_2: 0.1822 - auc_2: 0.7195 - val_loss: 0.9713 - val_accuracy: 0.4745 - val_precision_2: 0.6744 - val_recall_2: 0.1480 - val_auc_2: 0.7132
# Epoch 23/50
# 25/25 [==============================] - 86s 3s/step - loss: 0.9641 - accuracy: 0.5299 - precision_2: 0.7030 - recall_2: 0.1809 - auc_2: 0.7248 - val_loss: 0.9671 - val_accuracy: 0.5357 - val_precision_2: 0.6458 - val_recall_2: 0.1582 - val_auc_2: 0.7178
# Epoch 24/50
# 25/25 [==============================] - 128s 5s/step - loss: 0.9534 - accuracy: 0.5567 - precision_2: 0.7202 - recall_2: 0.1771 - auc_2: 0.7352 - val_loss: 0.9541 - val_accuracy: 0.5408 - val_precision_2: 0.6667 - val_recall_2: 0.1429 - val_auc_2: 0.7316
# Epoch 25/50
# 25/25 [==============================] - 89s 3s/step - loss: 0.9478 - accuracy: 0.5541 - precision_2: 0.6844 - recall_2: 0.1962 - auc_2: 0.7382 - val_loss: 0.9633 - val_accuracy: 0.4796 - val_precision_2: 0.5965 - val_recall_2: 0.1735 - val_auc_2: 0.7156
# Epoch 26/50
# 25/25 [==============================] - 71s 3s/step - loss: 0.9438 - accuracy: 0.5401 - precision_2: 0.6770 - recall_2: 0.1949 - auc_2: 0.7393 - val_loss: 0.9456 - val_accuracy: 0.5459 - val_precision_2: 0.6939 - val_recall_2: 0.1735 - val_auc_2: 0.7361
# Epoch 27/50
# 25/25 [==============================] - 74s 3s/step - loss: 0.9391 - accuracy: 0.5669 - precision_2: 0.6962 - recall_2: 0.2102 - auc_2: 0.7455 - val_loss: 0.9386 - val_accuracy: 0.5714 - val_precision_2: 0.6905 - val_recall_2: 0.1480 - val_auc_2: 0.7427
# Epoch 28/50
# 25/25 [==============================] - 81s 3s/step - loss: 0.9525 - accuracy: 0.5516 - precision_2: 0.7031 - recall_2: 0.2051 - auc_2: 0.7327 - val_loss: 0.9402 - val_accuracy: 0.5357 - val_precision_2: 0.6905 - val_recall_2: 0.1480 - val_auc_2: 0.7405
# Epoch 29/50
# 25/25 [==============================] - 77s 3s/step - loss: 0.9422 - accuracy: 0.5554 - precision_2: 0.6723 - recall_2: 0.2038 - auc_2: 0.7406 - val_loss: 0.9361 - val_accuracy: 0.5612 - val_precision_2: 0.7045 - val_recall_2: 0.1582 - val_auc_2: 0.7440
# Epoch 30/50
# 25/25 [==============================] - 108s 4s/step - loss: 0.9261 - accuracy: 0.5720 - precision_2: 0.7213 - recall_2: 0.2242 - auc_2: 0.7552 - val_loss: 0.9563 - val_accuracy: 0.4949 - val_precision_2: 0.6212 - val_recall_2: 0.2092 - val_auc_2: 0.7200
# Epoch 31/50
# 25/25 [==============================] - 85s 3s/step - loss: 0.9403 - accuracy: 0.5414 - precision_2: 0.6725 - recall_2: 0.2433 - auc_2: 0.7372 - val_loss: 0.9424 - val_accuracy: 0.5510 - val_precision_2: 0.6129 - val_recall_2: 0.1939 - val_auc_2: 0.7341
# Epoch 32/50
# 25/25 [==============================] - 79s 3s/step - loss: 0.9348 - accuracy: 0.5503 - precision_2: 0.6715 - recall_2: 0.2344 - auc_2: 0.7451 - val_loss: 0.9323 - val_accuracy: 0.5663 - val_precision_2: 0.6167 - val_recall_2: 0.1888 - val_auc_2: 0.7420
# Epoch 33/50
# 25/25 [==============================] - 81s 3s/step - loss: 0.9389 - accuracy: 0.5580 - precision_2: 0.6703 - recall_2: 0.2382 - auc_2: 0.7392 - val_loss: 0.9305 - val_accuracy: 0.5459 - val_precision_2: 0.6182 - val_recall_2: 0.1735 - val_auc_2: 0.7465
# Epoch 34/50
# 25/25 [==============================] - 87s 3s/step - loss: 0.9212 - accuracy: 0.5656 - precision_2: 0.6889 - recall_2: 0.2369 - auc_2: 0.7577 - val_loss: 0.9374 - val_accuracy: 0.5204 - val_precision_2: 0.6500 - val_recall_2: 0.1990 - val_auc_2: 0.7383
# Epoch 35/50
# 25/25 [==============================] - 85s 3s/step - loss: 0.9141 - accuracy: 0.5732 - precision_2: 0.6979 - recall_2: 0.2561 - auc_2: 0.7613 - val_loss: 0.9675 - val_accuracy: 0.4745 - val_precision_2: 0.5823 - val_recall_2: 0.2347 - val_auc_2: 0.7079
# Epoch 36/50
# 25/25 [==============================] - 78s 3s/step - loss: 0.9159 - accuracy: 0.5873 - precision_2: 0.7055 - recall_2: 0.2624 - auc_2: 0.7583 - val_loss: 0.9473 - val_accuracy: 0.4949 - val_precision_2: 0.6301 - val_recall_2: 0.2347 - val_auc_2: 0.7261
# Epoch 37/50
# 25/25 [==============================] - 84s 3s/step - loss: 0.9101 - accuracy: 0.5682 - precision_2: 0.6935 - recall_2: 0.2739 - auc_2: 0.7611 - val_loss: 0.9278 - val_accuracy: 0.5663 - val_precision_2: 0.6471 - val_recall_2: 0.2245 - val_auc_2: 0.7461
# Epoch 38/50
# 25/25 [==============================] - 80s 3s/step - loss: 0.9096 - accuracy: 0.5809 - precision_2: 0.6897 - recall_2: 0.2803 - auc_2: 0.7627 - val_loss: 0.9259 - val_accuracy: 0.5612 - val_precision_2: 0.5949 - val_recall_2: 0.2398 - val_auc_2: 0.7446
# Epoch 39/50
# 25/25 [==============================] - 73s 3s/step - loss: 0.9043 - accuracy: 0.5758 - precision_2: 0.7099 - recall_2: 0.2930 - auc_2: 0.7665 - val_loss: 0.9270 - val_accuracy: 0.5510 - val_precision_2: 0.6301 - val_recall_2: 0.2347 - val_auc_2: 0.7457
# Epoch 40/50
# 25/25 [==============================] - 76s 3s/step - loss: 0.8995 - accuracy: 0.5936 - precision_2: 0.6960 - recall_2: 0.2917 - auc_2: 0.7702 - val_loss: 0.9216 - val_accuracy: 0.5255 - val_precision_2: 0.6154 - val_recall_2: 0.2449 - val_auc_2: 0.7500
# Epoch 41/50
# 25/25 [==============================] - 89s 3s/step - loss: 0.8992 - accuracy: 0.5860 - precision_2: 0.6856 - recall_2: 0.2917 - auc_2: 0.7697 - val_loss: 0.9150 - val_accuracy: 0.5408 - val_precision_2: 0.6588 - val_recall_2: 0.2857 - val_auc_2: 0.7557
# Epoch 42/50
# 25/25 [==============================] - 98s 4s/step - loss: 0.8974 - accuracy: 0.5783 - precision_2: 0.6685 - recall_2: 0.3134 - auc_2: 0.7687 - val_loss: 0.9684 - val_accuracy: 0.4898 - val_precision_2: 0.5730 - val_recall_2: 0.2602 - val_auc_2: 0.7078
# Epoch 43/50
# 25/25 [==============================] - 74s 3s/step - loss: 0.8983 - accuracy: 0.5682 - precision_2: 0.6858 - recall_2: 0.3197 - auc_2: 0.7666 - val_loss: 0.9336 - val_accuracy: 0.5255 - val_precision_2: 0.5889 - val_recall_2: 0.2704 - val_auc_2: 0.7367
# Epoch 44/50
# 25/25 [==============================] - 73s 3s/step - loss: 0.8885 - accuracy: 0.5796 - precision_2: 0.6954 - recall_2: 0.3490 - auc_2: 0.7737 - val_loss: 0.9491 - val_accuracy: 0.5102 - val_precision_2: 0.5914 - val_recall_2: 0.2806 - val_auc_2: 0.7234
# Epoch 45/50
# 25/25 [==============================] - 82s 3s/step - loss: 0.8918 - accuracy: 0.5847 - precision_2: 0.6923 - recall_2: 0.3325 - auc_2: 0.7722 - val_loss: 0.9212 - val_accuracy: 0.5612 - val_precision_2: 0.5957 - val_recall_2: 0.2857 - val_auc_2: 0.7464
# Epoch 46/50
# 25/25 [==============================] - 94s 4s/step - loss: 0.8861 - accuracy: 0.5911 - precision_2: 0.6941 - recall_2: 0.3439 - auc_2: 0.7757 - val_loss: 0.9129 - val_accuracy: 0.5714 - val_precision_2: 0.6105 - val_recall_2: 0.2959 - val_auc_2: 0.7538
# Epoch 47/50
# 25/25 [==============================] - 71s 3s/step - loss: 0.8829 - accuracy: 0.5682 - precision_2: 0.6961 - recall_2: 0.3618 - auc_2: 0.7780 - val_loss: 0.9105 - val_accuracy: 0.5714 - val_precision_2: 0.6452 - val_recall_2: 0.3061 - val_auc_2: 0.7557
# Epoch 48/50
# 25/25 [==============================] - 110s 4s/step - loss: 0.8784 - accuracy: 0.5885 - precision_2: 0.7018 - recall_2: 0.3567 - auc_2: 0.7803 - val_loss: 0.9367 - val_accuracy: 0.5306 - val_precision_2: 0.5960 - val_recall_2: 0.3010 - val_auc_2: 0.7329
# Epoch 49/50
# 25/25 [==============================] - 80s 3s/step - loss: 0.8944 - accuracy: 0.5707 - precision_2: 0.6407 - recall_2: 0.3567 - auc_2: 0.7645 - val_loss: 0.9182 - val_accuracy: 0.5510 - val_precision_2: 0.5763 - val_recall_2: 0.3469 - val_auc_2: 0.7467
# Epoch 50/50
# 25/25 [==============================] - 70s 3s/step - loss: 0.8921 - accuracy: 0.5758 - precision_2: 0.6850 - recall_2: 0.3656 - auc_2: 0.7687 - val_loss: 0.9078 - val_accuracy: 0.5612 - val_precision_2: 0.6337 - val_recall_2: 0.3265 - val_auc_2: 0.7584

# %%
# Print the best epochs
best_epoch_loss = np.argmin(history.history['val_loss'])
best_epoch_accuracy = np.argmax(history.history['val_accuracy'])
print(f'Best Epoch for Validation Loss: {best_epoch_loss}')
print(f'Best Epoch for Validation Accuracy: {best_epoch_accuracy}')
# Out:
# Best Epoch for Validation Loss: 49
# Best Epoch for Validation Accuracy: 26

# %%
import matplotlib.pyplot as plt

# Plot training history for loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Mark the best epoch for validation loss
best_epoch_loss = np.argmin(history.history['val_loss'])
plt.axvline(x=best_epoch_loss, color='r', linestyle='--', label=f'Best Epoch Loss: {best_epoch_loss}')
plt.legend()

# Plot training history for accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Mark the best epoch for validation accuracy
best_epoch_accuracy = np.argmax(history.history['val_accuracy'])
plt.axvline(x=best_epoch_accuracy, color='r', linestyle='--', label=f'Best Epoch Accuracy: {best_epoch_accuracy}')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Print the best epochs
print(f'Best Epoch for Validation Loss: {best_epoch_loss}')
print(f'Best Epoch for Validation Accuracy: {best_epoch_accuracy}')
# Out:
# Best Epoch for Validation Loss: 49
# Best Epoch for Validation Accuracy: 26

# %% [markdown]
# # Model Testing and Evaluation

# %%
# Load and test an image of curly hair
img_curly = keras.preprocessing.image.load_img(
    "hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--layered-natural-hair-natural-black-hairstyles.jpg", target_size=image_size
)
img_array_curly = keras.preprocessing.image.img_to_array(img_curly)
img_array_curly = tf.expand_dims(img_array_curly, 0)  # Create batch axis

predictions_curly = model.predict(img_array_curly)
print(
    "CURLY: This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions_curly[0])
)

# Load and test an image of straight hair
img_straight = keras.preprocessing.image.load_img(
    "hair_types/Straight_Hair/1-short-spiky-mens-haircut.jpg", target_size=image_size
)
img_array_straight = keras.preprocessing.image.img_to_array(img_straight)
img_array_straight = tf.expand_dims(img_array_straight, 0)  # Create batch axis

predictions_straight = model.predict(img_array_straight)
print(
    "STRAIGHT: This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions_straight[0])
)

# Load and test an image of wavy hair
img_wavy = keras.preprocessing.image.load_img(
    "hair_types/Wavy_Hair/2-Short-High-Volume-Hairstyle.jpg", target_size=image_size
)
img_array_wavy = keras.preprocessing.image.img_to_array(img_wavy)
img_array_wavy = tf.expand_dims(img_array_wavy, 0)  # Create batch axis

predictions_wavy = model.predict(img_array_wavy)
print(
    "WAVY: This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions_wavy[0])
)
# Out:
# 1/1 [==============================] - 1s 958ms/step
# CURLY: This image is 0.62 percent curly hair, 0.21 percent straight hair, and 0.17 percent wavy hair.
# 1/1 [==============================] - 0s 74ms/step
# STRAIGHT: This image is 0.05 percent curly hair, 0.48 percent straight hair, and 0.48 percent wavy hair.
# 1/1 [==============================] - 0s 74ms/step
# WAVY: This image is 0.15 percent curly hair, 0.24 percent straight hair, and 0.61 percent wavy hair.

# %% [markdown]
# 1ADDED: give you insights into how well your model generalizes to new, unseen data based on your validation dataset

# %% [markdown]
# AUC = 0.5: The model performs no better than random chance.
#
# AUC < 0.5: The model performs worse than random chance.
#
# AUC > 0.5: The model has some discriminatory power, with higher values indicating better discrimination.

# %%
val_loss, val_accuracy, val_precision, val_recall, val_auc = model.evaluate(val_ds)
print(f"Validation Accuracy: {val_accuracy}")
print(f"Validation Precision: {val_precision}")
print(f"Validation Recall: {val_recall}")
print(f"Validation AUC: {val_auc}")
# Out:
# 7/7 [==============================] - 1s 86ms/step - loss: 0.9076 - accuracy: 0.5612 - precision_2: 0.6337 - recall_2: 0.3265 - auc_2: 0.7584
# Validation Accuracy: 0.5612244606018066
# Validation Precision: 0.6336633563041687
# Validation Recall: 0.3265306055545807
# Validation AUC: 0.7583559155464172

# %%
import tensorflow as tf
from tensorflow import keras

# Assuming val_ds is your validation dataset
val_images = []
val_labels = []

for images, labels in val_ds.take(3):  # Take 3 batches (adjust as needed)
    val_images.append(images)
    val_labels.append(labels)

# Concatenate the batches to get the images and labels
val_images = tf.concat(val_images, axis=0)
val_labels = tf.concat(val_labels, axis=0)

# Test the model on the selected validation images
predictions = model.predict(val_images)

for i in range(len(val_images)):
    print(f"Image {i + 1} - Filename: {val_filenames[i]}:")
    print(f"True Label: {val_labels[i]}")
    print(f"Predictions: {predictions[i]}")
    print()
# Out:
# 3/3 [==============================] - 0s 98ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Andrea Dayo\Documents\GitHub\CS-ELEC-1A-LabEx\LabEx3\Trial4.ipynb Cell 34 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/Andrea%20Dayo/Documents/GitHub/CS-ELEC-1A-LabEx/LabEx3/Trial4.ipynb#X43sZmlsZQ%3D%3D?line=16'>17</a> predictions = model.predict(val_images)
#      <a href='vscode-notebook-cell:/c%3A/Users/Andrea%20Dayo/Documents/GitHub/CS-ELEC-1A-LabEx/LabEx3/Trial4.ipynb#X43sZmlsZQ%3D%3D?line=18'>19</a> for i in range(len(val_images)):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Andrea%20Dayo/Documents/GitHub/CS-ELEC-1A-LabEx/LabEx3/Trial4.ipynb#X43sZmlsZQ%3D%3D?line=19'>20</a>     print(f"Image {i + 1} - Filename: {val_filenames[i]}:")
#      <a href='vscode-notebook-cell:/c%3A/Users/Andrea%20Dayo/Documents/GitHub/CS-ELEC-1A-LabEx/LabEx3/Trial4.ipynb#X43sZmlsZQ%3D%3D?line=20'>21</a>     print(f"True Label: {val_labels[i]}")
#      <a href='vscode-notebook-cell:/c%3A/Users/Andrea%20Dayo/Documents/GitHub/CS-ELEC-1A-LabEx/LabEx3/Trial4.ipynb#X43sZmlsZQ%3D%3D?line=21'>22</a>     print(f"Predictions: {predictions[i]}")
#
# NameError: name 'val_filenames' is not defined
