# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Preprocessing and Cleaning

# %%
from pathlib import Path
import imghdr
import os

data_dir = "hair_types"
image_extensions = [".png", ".jpg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]

for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        if filepath.exists():  # Check if the file exists before opening it
            img_type = imghdr.what(filepath)
            if img_type is None:
                print(f"{filepath} is not an image")
                os.remove(filepath)
            elif img_type not in img_type_accepted_by_tf:
                print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
                os.remove(filepath)
        else:
            print(f"{filepath} does not exist.")
# Out:
# hair_types\Straight_Hair\graphicstock-young-handsome-asiatic-long-brown-straight-hair-woman-taking-selfie-outdoor-in-the-city-with-a-smartphone-smiling-vanity-technology-social-network-concept_B6fyU2Ok-_SB_PM.jpg does not exist.
# hair_types\Straight_Hair\graphicstock-young-handsome-caucasian-reddish-straight-hair-woman-sitting-on-a-small-wall-holding-a-tablet-taking-a-selfie-doing-grimace-technology-social-network-youthful-concept_BTFpe2_1W_SB_PM.jpg does not exist.

# %% [markdown]
# # Data Loading and Splitting

# %% [markdown]
# 1ADDED: test_ds

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

image_size = (64, 64)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical'
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size, 
    labels='inferred',
    label_mode='categorical'
)
# Out:
# Found 981 files belonging to 3 classes.
# Using 785 files for training.
# Found 981 files belonging to 3 classes.
# Using 196 files for validation.

# %%
class_names = train_ds.class_names

# Count the number of samples per class in the training set
for class_name in class_names:
    num_samples = len([filename for filename in train_ds.file_paths if class_name in filename])
    print(f"Number of {class_name} samples in the training set: {num_samples}")

# Count the number of samples per class in the validation set
for class_name in class_names:
    num_samples = len([filename for filename in val_ds.file_paths if class_name in filename])
    print(f"Number of {class_name} samples in the validation set: {num_samples}")
# Out:
# Number of Curly_Hair samples in the training set: 276
# Number of Straight_Hair samples in the training set: 250
# Number of Wavy_Hair samples in the training set: 259
# Number of Curly_Hair samples in the validation set: 56
# Number of Straight_Hair samples in the validation set: 68
# Number of Wavy_Hair samples in the validation set: 72

# %% [markdown]
# # Mixed Precision Training and Data Prefetching

# %% [markdown]
# 1ADDED: Mixed Precision Training -  speed up training without sacrificing much in terms of accuracy

# %%
policy = tf.keras.mixed_precision.Policy('mixed_float16')
tf.keras.mixed_precision.set_global_policy(policy)

# %% [markdown]
# 1ADDED: Use the prefetch transformation to overlap the preprocessing and model execution of training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Visualization of Training Data

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(np.argmax(labels[i])))
        plt.axis("off")
plt.show()

# %% [markdown]
# # Model Architecture

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(keras.Input(shape=image_size + (3,))) # 64, 64, 3
model.add(layers.Rescaling(1.0 / 255))

model.add(layers.Conv2D(filters=4, kernel_size=16, strides=1, padding='valid', dilation_rate=2))
model.add(layers.Activation("relu"))

model.add(layers.Conv2D(filters=8, kernel_size=8, strides=1, padding='valid', dilation_rate=2))
model.add(layers.Activation("relu"))

model.add(layers.Conv2D(filters=16, kernel_size=4, strides=1, padding='valid', dilation_rate=2))
model.add(layers.Activation("relu"))

model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(64))
model.add(layers.Activation("relu"))
model.add(layers.Dense(3))
model.add(layers.Activation("softmax"))

# %% [markdown]
# # Visualizing Model Architecture

# %%
tf.keras.utils.plot_model(model, to_file='model_test.png', show_shapes=True)

# %% [markdown]
# # Display Model Summary

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 64, 64, 3)         0
#
#  conv2d_6 (Conv2D)           (None, 34, 34, 4)         3076
#
#  activation_10 (Activation)  (None, 34, 34, 4)         0
#
#  conv2d_7 (Conv2D)           (None, 20, 20, 8)         2056
#
#  activation_11 (Activation)  (None, 20, 20, 8)         0
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 16)        2064
#
#  activation_12 (Activation)  (None, 14, 14, 16)        0
#
#  global_average_pooling2d_2  (None, 16)                0
#   (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 64)                1088
#
#  activation_13 (Activation)  (None, 64)                0
#
#  dense_5 (Dense)             (None, 3)                 195
#
#  activation_14 (Activation)  (None, 3)                 0
#
# =================================================================
# Total params: 8479 (33.12 KB)
# Trainable params: 8479 (33.12 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Model Training

# %%
epochs = 50

model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()],
)

# %% [markdown]
# # Training the Model

# %%
history = model.fit(train_ds, epochs=epochs, validation_data=val_ds)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 103s 4s/step - loss: 0.9086 - accuracy: 0.5656 - precision_3: 0.6422 - recall_3: 0.3338 - auc_3: 0.7542 - val_loss: 1.0144 - val_accuracy: 0.4541 - val_precision_3: 0.5870 - val_recall_3: 0.2755 - val_auc_3: 0.6752
# Epoch 2/50
# 25/25 [==============================] - 108s 4s/step - loss: 0.9008 - accuracy: 0.5478 - precision_3: 0.6258 - recall_3: 0.3580 - auc_3: 0.7533 - val_loss: 1.0498 - val_accuracy: 0.4286 - val_precision_3: 0.4727 - val_recall_3: 0.2653 - val_auc_3: 0.6501
# Epoch 3/50
# 25/25 [==============================] - 116s 4s/step - loss: 0.9505 - accuracy: 0.5210 - precision_3: 0.6174 - recall_3: 0.3248 - auc_3: 0.7304 - val_loss: 1.0314 - val_accuracy: 0.4286 - val_precision_3: 0.5072 - val_recall_3: 0.1786 - val_auc_3: 0.6514
# Epoch 4/50
# 25/25 [==============================] - 118s 5s/step - loss: 0.9086 - accuracy: 0.5554 - precision_3: 0.6486 - recall_3: 0.3197 - auc_3: 0.7529 - val_loss: 1.0888 - val_accuracy: 0.4388 - val_precision_3: 0.4757 - val_recall_3: 0.2500 - val_auc_3: 0.6488
# Epoch 5/50
# 25/25 [==============================] - 121s 5s/step - loss: 0.8851 - accuracy: 0.5834 - precision_3: 0.6437 - recall_3: 0.3567 - auc_3: 0.7672 - val_loss: 1.0529 - val_accuracy: 0.4796 - val_precision_3: 0.5271 - val_recall_3: 0.3469 - val_auc_3: 0.6688
# Epoch 6/50
# 25/25 [==============================] - 112s 4s/step - loss: 0.8676 - accuracy: 0.5898 - precision_3: 0.6454 - recall_3: 0.4127 - auc_3: 0.7768 - val_loss: 1.0777 - val_accuracy: 0.4490 - val_precision_3: 0.5000 - val_recall_3: 0.2959 - val_auc_3: 0.6527
# Epoch 7/50
# 25/25 [==============================] - 143s 6s/step - loss: 0.8468 - accuracy: 0.5873 - precision_3: 0.6488 - recall_3: 0.4471 - auc_3: 0.7871 - val_loss: 1.0066 - val_accuracy: 0.5204 - val_precision_3: 0.5379 - val_recall_3: 0.3622 - val_auc_3: 0.6953
# Epoch 8/50
# 25/25 [==============================] - 118s 4s/step - loss: 0.8342 - accuracy: 0.6025 - precision_3: 0.6673 - recall_3: 0.4726 - auc_3: 0.7976 - val_loss: 1.0970 - val_accuracy: 0.5102 - val_precision_3: 0.5319 - val_recall_3: 0.3827 - val_auc_3: 0.6829
# Epoch 9/50
# 25/25 [==============================] - 117s 5s/step - loss: 0.8430 - accuracy: 0.5834 - precision_3: 0.6534 - recall_3: 0.4611 - auc_3: 0.7901 - val_loss: 1.0468 - val_accuracy: 0.5000 - val_precision_3: 0.5522 - val_recall_3: 0.3776 - val_auc_3: 0.6791
# Epoch 10/50
# 25/25 [==============================] - 59s 2s/step - loss: 0.8188 - accuracy: 0.6153 - precision_3: 0.6783 - recall_3: 0.5185 - auc_3: 0.8036 - val_loss: 1.0123 - val_accuracy: 0.5204 - val_precision_3: 0.5105 - val_recall_3: 0.3724 - val_auc_3: 0.7005
# Epoch 11/50
# 25/25 [==============================] - 60s 2s/step - loss: 0.8374 - accuracy: 0.5834 - precision_3: 0.6491 - recall_3: 0.4713 - auc_3: 0.7903 - val_loss: 1.0145 - val_accuracy: 0.4694 - val_precision_3: 0.5385 - val_recall_3: 0.3214 - val_auc_3: 0.6950
# Epoch 12/50
# 25/25 [==============================] - 60s 2s/step - loss: 0.8141 - accuracy: 0.6306 - precision_3: 0.6867 - recall_3: 0.5083 - auc_3: 0.8083 - val_loss: 1.0517 - val_accuracy: 0.4949 - val_precision_3: 0.5373 - val_recall_3: 0.3673 - val_auc_3: 0.6887
# Epoch 13/50
# 25/25 [==============================] - 68s 3s/step - loss: 0.8220 - accuracy: 0.5949 - precision_3: 0.6586 - recall_3: 0.4866 - auc_3: 0.8019 - val_loss: 1.1176 - val_accuracy: 0.4337 - val_precision_3: 0.4662 - val_recall_3: 0.3520 - val_auc_3: 0.6529
# Epoch 14/50
# 25/25 [==============================] - 50s 2s/step - loss: 0.8075 - accuracy: 0.6089 - precision_3: 0.6855 - recall_3: 0.4943 - auc_3: 0.8122 - val_loss: 1.0409 - val_accuracy: 0.5153 - val_precision_3: 0.5473 - val_recall_3: 0.4133 - val_auc_3: 0.6941
# Epoch 15/50
# 25/25 [==============================] - 49s 2s/step - loss: 0.7979 - accuracy: 0.6357 - precision_3: 0.6931 - recall_3: 0.5350 - auc_3: 0.8189 - val_loss: 1.0287 - val_accuracy: 0.4847 - val_precision_3: 0.5224 - val_recall_3: 0.3571 - val_auc_3: 0.6834
# Epoch 16/50
# 25/25 [==============================] - 63s 2s/step - loss: 0.7962 - accuracy: 0.6229 - precision_3: 0.6770 - recall_3: 0.5261 - auc_3: 0.8163 - val_loss: 1.0574 - val_accuracy: 0.4796 - val_precision_3: 0.5099 - val_recall_3: 0.3929 - val_auc_3: 0.6859
# Epoch 17/50
# 25/25 [==============================] - 55s 2s/step - loss: 0.8043 - accuracy: 0.6166 - precision_3: 0.6908 - recall_3: 0.4981 - auc_3: 0.8127 - val_loss: 1.0126 - val_accuracy: 0.5204 - val_precision_3: 0.5692 - val_recall_3: 0.3776 - val_auc_3: 0.7140
# Epoch 18/50
# 25/25 [==============================] - 56s 2s/step - loss: 0.7689 - accuracy: 0.6255 - precision_3: 0.6865 - recall_3: 0.5439 - auc_3: 0.8279 - val_loss: 1.0753 - val_accuracy: 0.5153 - val_precision_3: 0.5390 - val_recall_3: 0.3878 - val_auc_3: 0.6986
# Epoch 19/50
# 25/25 [==============================] - 58s 2s/step - loss: 0.8318 - accuracy: 0.6000 - precision_3: 0.6764 - recall_3: 0.4713 - auc_3: 0.7976 - val_loss: 0.9634 - val_accuracy: 0.5408 - val_precision_3: 0.5965 - val_recall_3: 0.3469 - val_auc_3: 0.7212
# Epoch 20/50
# 25/25 [==============================] - 60s 2s/step - loss: 0.7791 - accuracy: 0.6382 - precision_3: 0.6912 - recall_3: 0.5503 - auc_3: 0.8246 - val_loss: 1.0085 - val_accuracy: 0.5153 - val_precision_3: 0.5548 - val_recall_3: 0.4133 - val_auc_3: 0.7104
# Epoch 21/50
# 25/25 [==============================] - 55s 2s/step - loss: 0.7578 - accuracy: 0.6433 - precision_3: 0.7074 - recall_3: 0.5452 - auc_3: 0.8349 - val_loss: 0.9812 - val_accuracy: 0.5255 - val_precision_3: 0.5778 - val_recall_3: 0.3980 - val_auc_3: 0.7177
# Epoch 22/50
# 25/25 [==============================] - 56s 2s/step - loss: 0.7513 - accuracy: 0.6573 - precision_3: 0.7229 - recall_3: 0.5783 - auc_3: 0.8365 - val_loss: 0.9805 - val_accuracy: 0.5357 - val_precision_3: 0.5764 - val_recall_3: 0.4235 - val_auc_3: 0.7300
# Epoch 23/50
# 25/25 [==============================] - 62s 2s/step - loss: 0.7717 - accuracy: 0.6344 - precision_3: 0.6910 - recall_3: 0.5185 - auc_3: 0.8265 - val_loss: 1.0414 - val_accuracy: 0.5051 - val_precision_3: 0.5643 - val_recall_3: 0.4031 - val_auc_3: 0.7063
# Epoch 24/50
# 25/25 [==============================] - 52s 2s/step - loss: 0.7662 - accuracy: 0.6395 - precision_3: 0.6880 - recall_3: 0.5478 - auc_3: 0.8303 - val_loss: 1.0236 - val_accuracy: 0.5102 - val_precision_3: 0.5659 - val_recall_3: 0.3724 - val_auc_3: 0.7099
# Epoch 25/50
# 25/25 [==============================] - 57s 2s/step - loss: 0.7575 - accuracy: 0.6395 - precision_3: 0.7005 - recall_3: 0.5363 - auc_3: 0.8357 - val_loss: 1.0083 - val_accuracy: 0.5102 - val_precision_3: 0.5625 - val_recall_3: 0.4133 - val_auc_3: 0.7227
# Epoch 26/50
# 25/25 [==============================] - 55s 2s/step - loss: 0.7760 - accuracy: 0.6446 - precision_3: 0.6830 - recall_3: 0.5516 - auc_3: 0.8268 - val_loss: 1.0003 - val_accuracy: 0.5255 - val_precision_3: 0.5968 - val_recall_3: 0.3776 - val_auc_3: 0.7106
# Epoch 27/50
# 25/25 [==============================] - 52s 2s/step - loss: 0.7717 - accuracy: 0.6433 - precision_3: 0.7031 - recall_3: 0.5159 - auc_3: 0.8308 - val_loss: 1.0105 - val_accuracy: 0.5204 - val_precision_3: 0.5563 - val_recall_3: 0.4031 - val_auc_3: 0.7176
# Epoch 28/50
# 25/25 [==============================] - 55s 2s/step - loss: 0.7244 - accuracy: 0.6726 - precision_3: 0.7302 - recall_3: 0.5860 - auc_3: 0.8519 - val_loss: 1.0374 - val_accuracy: 0.5051 - val_precision_3: 0.5570 - val_recall_3: 0.4235 - val_auc_3: 0.7172
# Epoch 29/50
# 25/25 [==============================] - 54s 2s/step - loss: 0.7173 - accuracy: 0.6535 - precision_3: 0.7391 - recall_3: 0.5847 - auc_3: 0.8545 - val_loss: 1.0250 - val_accuracy: 0.4898 - val_precision_3: 0.5570 - val_recall_3: 0.4235 - val_auc_3: 0.7143
# Epoch 30/50
# 25/25 [==============================] - 54s 2s/step - loss: 0.7247 - accuracy: 0.6459 - precision_3: 0.7147 - recall_3: 0.5682 - auc_3: 0.8499 - val_loss: 1.0362 - val_accuracy: 0.5663 - val_precision_3: 0.5878 - val_recall_3: 0.4439 - val_auc_3: 0.7227
# Epoch 31/50
# 25/25 [==============================] - 57s 2s/step - loss: 0.6953 - accuracy: 0.6752 - precision_3: 0.7377 - recall_3: 0.6127 - auc_3: 0.8638 - val_loss: 1.0275 - val_accuracy: 0.5357 - val_precision_3: 0.5912 - val_recall_3: 0.4796 - val_auc_3: 0.7288
# Epoch 32/50
# 25/25 [==============================] - 53s 2s/step - loss: 0.6998 - accuracy: 0.6841 - precision_3: 0.7266 - recall_3: 0.6025 - auc_3: 0.8620 - val_loss: 1.0060 - val_accuracy: 0.5612 - val_precision_3: 0.5987 - val_recall_3: 0.4796 - val_auc_3: 0.7333
# Epoch 33/50
# 25/25 [==============================] - 54s 2s/step - loss: 0.6862 - accuracy: 0.6739 - precision_3: 0.7296 - recall_3: 0.6051 - auc_3: 0.8671 - val_loss: 1.0295 - val_accuracy: 0.5357 - val_precision_3: 0.5660 - val_recall_3: 0.4592 - val_auc_3: 0.7278
# Epoch 34/50
# 25/25 [==============================] - 56s 2s/step - loss: 0.6844 - accuracy: 0.6841 - precision_3: 0.7373 - recall_3: 0.6115 - auc_3: 0.8664 - val_loss: 1.0212 - val_accuracy: 0.5408 - val_precision_3: 0.5833 - val_recall_3: 0.4643 - val_auc_3: 0.7304
# Epoch 35/50
# 25/25 [==============================] - 54s 2s/step - loss: 0.6910 - accuracy: 0.6943 - precision_3: 0.7344 - recall_3: 0.6306 - auc_3: 0.8683 - val_loss: 1.0332 - val_accuracy: 0.5459 - val_precision_3: 0.5563 - val_recall_3: 0.4286 - val_auc_3: 0.7257
# Epoch 36/50
# 25/25 [==============================] - 51s 2s/step - loss: 0.6779 - accuracy: 0.6917 - precision_3: 0.7531 - recall_3: 0.6102 - auc_3: 0.8729 - val_loss: 1.0340 - val_accuracy: 0.5153 - val_precision_3: 0.5723 - val_recall_3: 0.4643 - val_auc_3: 0.7291
# Epoch 37/50
# 25/25 [==============================] - 56s 2s/step - loss: 0.6768 - accuracy: 0.6879 - precision_3: 0.7274 - recall_3: 0.6255 - auc_3: 0.8693 - val_loss: 1.0094 - val_accuracy: 0.5408 - val_precision_3: 0.5723 - val_recall_3: 0.4643 - val_auc_3: 0.7334
# Epoch 38/50
# 25/25 [==============================] - 54s 2s/step - loss: 0.6751 - accuracy: 0.6854 - precision_3: 0.7360 - recall_3: 0.6217 - auc_3: 0.8715 - val_loss: 1.0117 - val_accuracy: 0.5357 - val_precision_3: 0.5583 - val_recall_3: 0.4643 - val_auc_3: 0.7384
# Epoch 39/50
# 25/25 [==============================] - 54s 2s/step - loss: 0.6514 - accuracy: 0.6994 - precision_3: 0.7526 - recall_3: 0.6433 - auc_3: 0.8816 - val_loss: 1.0663 - val_accuracy: 0.5408 - val_precision_3: 0.5652 - val_recall_3: 0.4643 - val_auc_3: 0.7352
# Epoch 40/50
# 25/25 [==============================] - 54s 2s/step - loss: 0.6448 - accuracy: 0.7083 - precision_3: 0.7645 - recall_3: 0.6535 - auc_3: 0.8851 - val_loss: 1.0387 - val_accuracy: 0.5459 - val_precision_3: 0.5641 - val_recall_3: 0.4490 - val_auc_3: 0.7320
# Epoch 41/50
# 25/25 [==============================] - 54s 2s/step - loss: 0.6392 - accuracy: 0.6943 - precision_3: 0.7519 - recall_3: 0.6408 - auc_3: 0.8844 - val_loss: 1.0414 - val_accuracy: 0.5459 - val_precision_3: 0.5660 - val_recall_3: 0.4592 - val_auc_3: 0.7401
# Epoch 42/50
# 25/25 [==============================] - 62s 2s/step - loss: 0.6477 - accuracy: 0.7057 - precision_3: 0.7590 - recall_3: 0.6420 - auc_3: 0.8843 - val_loss: 1.0680 - val_accuracy: 0.4898 - val_precision_3: 0.5280 - val_recall_3: 0.4337 - val_auc_3: 0.7197
# Epoch 43/50
# 25/25 [==============================] - 60s 2s/step - loss: 0.6211 - accuracy: 0.7032 - precision_3: 0.7658 - recall_3: 0.6497 - auc_3: 0.8932 - val_loss: 1.0618 - val_accuracy: 0.5408 - val_precision_3: 0.5536 - val_recall_3: 0.4745 - val_auc_3: 0.7355
# Epoch 44/50
# 25/25 [==============================] - 55s 2s/step - loss: 0.6098 - accuracy: 0.7197 - precision_3: 0.7678 - recall_3: 0.6739 - auc_3: 0.8969 - val_loss: 1.0945 - val_accuracy: 0.5306 - val_precision_3: 0.5422 - val_recall_3: 0.4592 - val_auc_3: 0.7320
# Epoch 45/50
# 25/25 [==============================] - 56s 2s/step - loss: 0.6382 - accuracy: 0.7096 - precision_3: 0.7529 - recall_3: 0.6561 - auc_3: 0.8866 - val_loss: 1.1104 - val_accuracy: 0.5153 - val_precision_3: 0.5562 - val_recall_3: 0.4541 - val_auc_3: 0.7227
# Epoch 46/50
# 25/25 [==============================] - 65s 3s/step - loss: 0.6229 - accuracy: 0.7287 - precision_3: 0.7795 - recall_3: 0.6573 - auc_3: 0.8933 - val_loss: 1.0407 - val_accuracy: 0.5204 - val_precision_3: 0.5402 - val_recall_3: 0.4796 - val_auc_3: 0.7349
# Epoch 47/50
# 25/25 [==============================] - 40s 2s/step - loss: 0.5930 - accuracy: 0.7287 - precision_3: 0.7787 - recall_3: 0.6904 - auc_3: 0.9030 - val_loss: 1.1627 - val_accuracy: 0.5204 - val_precision_3: 0.5494 - val_recall_3: 0.4541 - val_auc_3: 0.7237
# Epoch 48/50
# 25/25 [==============================] - 55s 2s/step - loss: 0.6724 - accuracy: 0.6994 - precision_3: 0.7462 - recall_3: 0.6331 - auc_3: 0.8747 - val_loss: 1.1500 - val_accuracy: 0.5204 - val_precision_3: 0.5472 - val_recall_3: 0.4439 - val_auc_3: 0.7070
# Epoch 49/50
# 25/25 [==============================] - 62s 2s/step - loss: 0.6457 - accuracy: 0.6943 - precision_3: 0.7387 - recall_3: 0.6268 - auc_3: 0.8832 - val_loss: 1.0956 - val_accuracy: 0.5255 - val_precision_3: 0.5482 - val_recall_3: 0.4643 - val_auc_3: 0.7317
# Epoch 50/50
# 25/25 [==============================] - 71s 3s/step - loss: 0.5920 - accuracy: 0.7452 - precision_3: 0.7908 - recall_3: 0.6790 - auc_3: 0.9058 - val_loss: 1.1219 - val_accuracy: 0.5102 - val_precision_3: 0.5449 - val_recall_3: 0.4643 - val_auc_3: 0.7340

# %%
import matplotlib.pyplot as plt

# Plot training history for loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Mark the best epoch for validation loss
best_epoch_loss = np.argmin(history.history['val_loss'])
plt.axvline(x=best_epoch_loss, color='r', linestyle='--', label=f'Best Epoch Loss: {best_epoch_loss}')
plt.legend()

# Plot training history for accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Mark the best epoch for validation accuracy
best_epoch_accuracy = np.argmax(history.history['val_accuracy'])
plt.axvline(x=best_epoch_accuracy, color='r', linestyle='--', label=f'Best Epoch Accuracy: {best_epoch_accuracy}')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Print the best epochs
print(f'Best Epoch for Validation Loss: {best_epoch_loss}')
print(f'Best Epoch for Validation Accuracy: {best_epoch_accuracy}')
# Out:
# Best Epoch for Validation Loss: 18
# Best Epoch for Validation Accuracy: 29

# %%
# Print the best epochs
print(f'Best Epoch for Validation Loss: {best_epoch_loss}')
print(f'Best Epoch for Validation Accuracy: {best_epoch_accuracy}')
# Out:
# Best Epoch for Validation Loss: 18
# Best Epoch for Validation Accuracy: 29

# %% [markdown]
# # Model Testing and Evaluation

# %%
# Load and test an image of curly hair
img_curly = keras.preprocessing.image.load_img(
    "hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--layered-natural-hair-natural-black-hairstyles.jpg", target_size=image_size
)
img_array_curly = keras.preprocessing.image.img_to_array(img_curly)
img_array_curly = tf.expand_dims(img_array_curly, 0)  # Create batch axis

predictions_curly = model.predict(img_array_curly)
print(
    "CURLY: This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions_curly[0])
)

# Load and test an image of straight hair
img_straight = keras.preprocessing.image.load_img(
    "hair_types/Straight_Hair/1-short-spiky-mens-haircut.jpg", target_size=image_size
)
img_array_straight = keras.preprocessing.image.img_to_array(img_straight)
img_array_straight = tf.expand_dims(img_array_straight, 0)  # Create batch axis

predictions_straight = model.predict(img_array_straight)
print(
    "STRAIGHT: This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions_straight[0])
)

# Load and test an image of wavy hair
img_wavy = keras.preprocessing.image.load_img(
    "hair_types/Wavy_Hair/2-Short-High-Volume-Hairstyle.jpg", target_size=image_size
)
img_array_wavy = keras.preprocessing.image.img_to_array(img_wavy)
img_array_wavy = tf.expand_dims(img_array_wavy, 0)  # Create batch axis

predictions_wavy = model.predict(img_array_wavy)
print(
    "WAVY: This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions_wavy[0])
)
# Out:
# 1/1 [==============================] - 1s 625ms/step
# CURLY: This image is 0.99 percent curly hair, 0.01 percent straight hair, and 0.00 percent wavy hair.
# 1/1 [==============================] - 0s 66ms/step
# STRAIGHT: This image is 0.00 percent curly hair, 0.95 percent straight hair, and 0.05 percent wavy hair.
# 1/1 [==============================] - 0s 80ms/step
# WAVY: This image is 0.10 percent curly hair, 0.07 percent straight hair, and 0.83 percent wavy hair.

# %% [markdown]
# 1ADDED: give you insights into how well your model generalizes to new, unseen data based on your validation dataset

# %% [markdown]
# AUC = 0.5: The model performs no better than random chance.
#
# AUC < 0.5: The model performs worse than random chance.
#
# AUC > 0.5: The model has some discriminatory power, with higher values indicating better discrimination.

# %%
val_loss, val_accuracy, val_precision, val_recall, val_auc = model.evaluate(val_ds)
print(f"Validation Accuracy: {val_accuracy}")
print(f"Validation Precision: {val_precision}")
print(f"Validation Recall: {val_recall}")
print(f"Validation AUC: {val_auc}")
# Out:
# 7/7 [==============================] - 1s 57ms/step - loss: 1.1224 - accuracy: 0.5102 - precision_3: 0.5449 - recall_3: 0.4643 - auc_3: 0.7340
# Validation Accuracy: 0.5102040767669678
# Validation Precision: 0.544910192489624
# Validation Recall: 0.4642857015132904
# Validation AUC: 0.7339520454406738

# %%
import tensorflow as tf
from tensorflow import keras

# Assuming val_ds is your validation dataset
val_images = []
val_labels = []

for images, labels in val_ds.take(3):  # Take 3 batches (adjust as needed)
    val_images.append(images)
    val_labels.append(labels)

# Concatenate the batches to get the images and labels
val_images = tf.concat(val_images, axis=0)
val_labels = tf.concat(val_labels, axis=0)

# Test the model on the selected validation images
predictions = model.predict(val_images)

for i in range(len(val_images)):
    print(f"Image {i + 1} - Filename: {val_filenames[i]}:")
    print(f"True Label: {val_labels[i]}")
    print(f"Predictions: {predictions[i]}")
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Andrea Dayo\Documents\GitHub\CS-ELEC-1A-LabEx\LabEx3\Trial2-basis.ipynb Cell 32 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/Andrea%20Dayo/Documents/GitHub/CS-ELEC-1A-LabEx/LabEx3/Trial2-basis.ipynb#X46sZmlsZQ%3D%3D?line=4'>5</a> val_images = []
#       <a href='vscode-notebook-cell:/c%3A/Users/Andrea%20Dayo/Documents/GitHub/CS-ELEC-1A-LabEx/LabEx3/Trial2-basis.ipynb#X46sZmlsZQ%3D%3D?line=5'>6</a> val_labels = []
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Andrea%20Dayo/Documents/GitHub/CS-ELEC-1A-LabEx/LabEx3/Trial2-basis.ipynb#X46sZmlsZQ%3D%3D?line=7'>8</a> for images, labels in val_ds.take(3):  # Take 3 batches (adjust as needed)
#       <a href='vscode-notebook-cell:/c%3A/Users/Andrea%20Dayo/Documents/GitHub/CS-ELEC-1A-LabEx/LabEx3/Trial2-basis.ipynb#X46sZmlsZQ%3D%3D?line=8'>9</a>     val_images.append(images)
#      <a href='vscode-notebook-cell:/c%3A/Users/Andrea%20Dayo/Documents/GitHub/CS-ELEC-1A-LabEx/LabEx3/Trial2-basis.ipynb#X46sZmlsZQ%3D%3D?line=9'>10</a>     val_labels.append(labels)
#
# NameError: name 'val_ds' is not defined
