# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from pathlib import Path
import imghdr
import os

data_dir = "../hair_types"
image_extensions = [".png", ".jpg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]

for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        if filepath.exists():  # Check if the file exists before opening it
            img_type = imghdr.what(filepath)
            if img_type is None:
                print(f"{filepath} is not an image")
                os.remove(filepath)
            elif img_type not in img_type_accepted_by_tf:
                print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
                os.remove(filepath)
        else:
            print(f"{filepath} does not exist.")
# Out:
# ..\hair_types\Straight_Hair\graphicstock-half-length-of-young-handsome-caucasian-reddish-straight-hair-woman-taking-a-selfie-looking-in-camera-smiling-vanity-social-network-concept_BaZNfnukZ_SB_PM.jpg does not exist.
# ..\hair_types\Straight_Hair\graphicstock-young-handsome-asiatic-long-brown-straight-hair-woman-taking-selfie-outdoor-in-the-city-with-a-smartphone-smiling-vanity-technology-social-network-concept_B6fyU2Ok-_SB_PM.jpg does not exist.
# ..\hair_types\Straight_Hair\graphicstock-young-handsome-caucasian-reddish-straight-hair-woman-sitting-on-a-small-wall-holding-a-tablet-taking-a-selfie-doing-grimace-technology-social-network-youthful-concept_BTFpe2_1W_SB_PM.jpg does not exist.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

image_size = (64, 64)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../hair_types",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical'
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../hair_types",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size, 
    labels='inferred',
    label_mode='categorical'
)
# Out:
# Found 981 files belonging to 3 classes.
# Using 785 files for training.
# Found 981 files belonging to 3 classes.
# Using 196 files for validation.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(np.argmax(labels[i])))
        plt.axis("off")
plt.show()

# %% [markdown]
# - 0 curly hair
# - 1 straight hair
# - 2 wavy hair

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(keras.Input(shape=image_size + (3,))) # 64, 64, 3
model.add(layers.Rescaling(1.0 / 255))

model.add(layers.Conv2D(filters=4, kernel_size=16, strides=1, padding='valid', dilation_rate=1))
model.add(layers.Activation("relu"))

model.add(layers.Conv2D(filters=8, kernel_size=8, strides=1, padding='valid', dilation_rate=1))
model.add(layers.Activation("relu"))

model.add(layers.Conv2D(filters=16, kernel_size=4, strides=1, padding='valid', dilation_rate=1))
model.add(layers.Activation("relu"))

model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(64))
model.add(layers.Activation("relu"))
model.add(layers.Dense(3))
model.add(layers.Activation("softmax"))

# %% [markdown]
# model.add is used to add layers
#
# 3 = 3 channels
#
# rescaling layer to normalize the values from 0 to 1
#
# dilation rate - 1 lang siya kasi magkakatabi lang siya, if dagdagan magkakaroon ng spaces in between

# %%
tf.keras.utils.plot_model(model, to_file='model_test.png', show_shapes=True)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 64, 64, 3)         0
#
#  conv2d (Conv2D)             (None, 49, 49, 4)         3076
#
#  activation (Activation)     (None, 49, 49, 4)         0
#
#  conv2d_1 (Conv2D)           (None, 42, 42, 8)         2056
#
#  activation_1 (Activation)   (None, 42, 42, 8)         0
#
#  conv2d_2 (Conv2D)           (None, 39, 39, 16)        2064
#
#  activation_2 (Activation)   (None, 39, 39, 16)        0
#
#  global_average_pooling2d (  (None, 16)                0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 64)                1088
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dense_1 (Dense)             (None, 3)                 195
#
#  activation_4 (Activation)   (None, 3)                 0
#
# =================================================================
# Total params: 8479 (33.12 KB)
# Trainable params: 8479 (33.12 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 50

model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()],
)

history = model.fit(train_ds, epochs=epochs, validation_data=val_ds)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 11s 315ms/step - loss: 1.1005 - accuracy: 0.3274 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.4847 - val_loss: 1.0991 - val_accuracy: 0.2857 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4802
# Epoch 2/50
# 25/25 [==============================] - 8s 298ms/step - loss: 1.0975 - accuracy: 0.3682 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5216 - val_loss: 1.0960 - val_accuracy: 0.4031 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5599
# Epoch 3/50
# 25/25 [==============================] - 13s 444ms/step - loss: 1.0955 - accuracy: 0.3834 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5514 - val_loss: 1.0978 - val_accuracy: 0.3010 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5232
# Epoch 4/50
# 25/25 [==============================] - 12s 414ms/step - loss: 1.0973 - accuracy: 0.3503 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5293 - val_loss: 1.1057 - val_accuracy: 0.2857 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4657
# Epoch 5/50
# 25/25 [==============================] - 13s 490ms/step - loss: 1.0985 - accuracy: 0.3516 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5106 - val_loss: 1.1051 - val_accuracy: 0.2857 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4694
# Epoch 6/50
# 25/25 [==============================] - 13s 439ms/step - loss: 1.0979 - accuracy: 0.3516 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5178 - val_loss: 1.1028 - val_accuracy: 0.2857 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4925
# Epoch 7/50
# 25/25 [==============================] - 11s 408ms/step - loss: 1.0935 - accuracy: 0.3516 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5450 - val_loss: 1.1002 - val_accuracy: 0.2857 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5180
# Epoch 8/50
# 25/25 [==============================] - 12s 435ms/step - loss: 1.0682 - accuracy: 0.3643 - precision: 0.6327 - recall: 0.0790 - auc: 0.5903 - val_loss: 1.0886 - val_accuracy: 0.3622 - val_precision: 0.5500 - val_recall: 0.0561 - val_auc: 0.5643
# Epoch 9/50
# 25/25 [==============================] - 13s 456ms/step - loss: 1.0559 - accuracy: 0.4471 - precision: 0.6369 - recall: 0.1274 - auc: 0.6402 - val_loss: 1.0844 - val_accuracy: 0.3878 - val_precision: 0.5278 - val_recall: 0.0969 - val_auc: 0.5887
# Epoch 10/50
# 25/25 [==============================] - 13s 450ms/step - loss: 1.0246 - accuracy: 0.4675 - precision: 0.6977 - recall: 0.1529 - auc: 0.6699 - val_loss: 1.1087 - val_accuracy: 0.3980 - val_precision: 0.4444 - val_recall: 0.1429 - val_auc: 0.5972
# Epoch 11/50
# 25/25 [==============================] - 13s 475ms/step - loss: 1.0189 - accuracy: 0.4815 - precision: 0.6461 - recall: 0.1465 - auc: 0.6777 - val_loss: 1.0871 - val_accuracy: 0.3980 - val_precision: 0.4590 - val_recall: 0.1429 - val_auc: 0.6029
# Epoch 12/50
# 25/25 [==============================] - 15s 505ms/step - loss: 1.0037 - accuracy: 0.4790 - precision: 0.6683 - recall: 0.1720 - auc: 0.6835 - val_loss: 1.0501 - val_accuracy: 0.4235 - val_precision: 0.5312 - val_recall: 0.0867 - val_auc: 0.6284
# Epoch 13/50
# 25/25 [==============================] - 15s 537ms/step - loss: 0.9864 - accuracy: 0.4994 - precision: 0.6789 - recall: 0.1885 - auc: 0.6968 - val_loss: 1.0484 - val_accuracy: 0.4286 - val_precision: 0.5455 - val_recall: 0.0918 - val_auc: 0.6319
# Epoch 14/50
# 25/25 [==============================] - 16s 556ms/step - loss: 0.9875 - accuracy: 0.4930 - precision: 0.6699 - recall: 0.1758 - auc: 0.6927 - val_loss: 1.0721 - val_accuracy: 0.4082 - val_precision: 0.4590 - val_recall: 0.1429 - val_auc: 0.6196
# Epoch 15/50
# 25/25 [==============================] - 14s 475ms/step - loss: 0.9800 - accuracy: 0.5006 - precision: 0.6653 - recall: 0.2025 - auc: 0.7031 - val_loss: 1.0513 - val_accuracy: 0.4337 - val_precision: 0.5000 - val_recall: 0.0357 - val_auc: 0.6336
# Epoch 16/50
# 25/25 [==============================] - 13s 450ms/step - loss: 0.9829 - accuracy: 0.4879 - precision: 0.6834 - recall: 0.1732 - auc: 0.6942 - val_loss: 1.0771 - val_accuracy: 0.4082 - val_precision: 0.4590 - val_recall: 0.1429 - val_auc: 0.6208
# Epoch 17/50
# 25/25 [==============================] - 17s 595ms/step - loss: 0.9734 - accuracy: 0.4917 - precision: 0.6858 - recall: 0.1975 - auc: 0.7054 - val_loss: 1.0420 - val_accuracy: 0.4337 - val_precision: 0.5758 - val_recall: 0.0969 - val_auc: 0.6386
# Epoch 18/50
# 25/25 [==============================] - 21s 722ms/step - loss: 0.9857 - accuracy: 0.4854 - precision: 0.6908 - recall: 0.1822 - auc: 0.6943 - val_loss: 1.1221 - val_accuracy: 0.4031 - val_precision: 0.4430 - val_recall: 0.1786 - val_auc: 0.6022
# Epoch 19/50
# 25/25 [==============================] - 17s 609ms/step - loss: 0.9799 - accuracy: 0.4930 - precision: 0.6624 - recall: 0.1975 - auc: 0.6970 - val_loss: 1.0763 - val_accuracy: 0.3929 - val_precision: 0.4375 - val_recall: 0.1429 - val_auc: 0.6188
# Epoch 20/50
# 25/25 [==============================] - 19s 630ms/step - loss: 0.9650 - accuracy: 0.4994 - precision: 0.6787 - recall: 0.1911 - auc: 0.7099 - val_loss: 1.0598 - val_accuracy: 0.4133 - val_precision: 0.4815 - val_recall: 0.1327 - val_auc: 0.6268
# Epoch 21/50
# 25/25 [==============================] - 12s 411ms/step - loss: 0.9657 - accuracy: 0.4981 - precision: 0.7104 - recall: 0.2000 - auc: 0.7105 - val_loss: 1.0415 - val_accuracy: 0.4286 - val_precision: 0.5610 - val_recall: 0.1173 - val_auc: 0.6393
# Epoch 22/50
# 25/25 [==============================] - 20s 692ms/step - loss: 0.9615 - accuracy: 0.5019 - precision: 0.6694 - recall: 0.2064 - auc: 0.7102 - val_loss: 1.0736 - val_accuracy: 0.4082 - val_precision: 0.4655 - val_recall: 0.1378 - val_auc: 0.6237
# Epoch 23/50
# 25/25 [==============================] - 18s 618ms/step - loss: 0.9559 - accuracy: 0.5134 - precision: 0.7119 - recall: 0.2140 - auc: 0.7156 - val_loss: 1.0281 - val_accuracy: 0.4439 - val_precision: 0.6471 - val_recall: 0.1122 - val_auc: 0.6546
# Epoch 24/50
# 25/25 [==============================] - 19s 655ms/step - loss: 0.9627 - accuracy: 0.4943 - precision: 0.7117 - recall: 0.2013 - auc: 0.7128 - val_loss: 1.0354 - val_accuracy: 0.4184 - val_precision: 0.5800 - val_recall: 0.1480 - val_auc: 0.6486
# Epoch 25/50
# 25/25 [==============================] - 19s 649ms/step - loss: 0.9448 - accuracy: 0.5096 - precision: 0.7104 - recall: 0.2000 - auc: 0.7243 - val_loss: 1.0558 - val_accuracy: 0.4235 - val_precision: 0.5185 - val_recall: 0.1429 - val_auc: 0.6399
# Epoch 26/50
# 25/25 [==============================] - 19s 687ms/step - loss: 0.9544 - accuracy: 0.5057 - precision: 0.6936 - recall: 0.2076 - auc: 0.7151 - val_loss: 1.0496 - val_accuracy: 0.4286 - val_precision: 0.5750 - val_recall: 0.1173 - val_auc: 0.6382
# Epoch 27/50
# 25/25 [==============================] - 21s 707ms/step - loss: 0.9516 - accuracy: 0.4994 - precision: 0.6936 - recall: 0.2076 - auc: 0.7198 - val_loss: 1.0307 - val_accuracy: 0.4439 - val_precision: 0.6154 - val_recall: 0.1224 - val_auc: 0.6533
# Epoch 28/50
# 25/25 [==============================] - 20s 692ms/step - loss: 0.9439 - accuracy: 0.5172 - precision: 0.7309 - recall: 0.2076 - auc: 0.7239 - val_loss: 1.0262 - val_accuracy: 0.4388 - val_precision: 0.6562 - val_recall: 0.1071 - val_auc: 0.6632
# Epoch 29/50
# 25/25 [==============================] - 19s 656ms/step - loss: 0.9412 - accuracy: 0.5121 - precision: 0.7189 - recall: 0.1987 - auc: 0.7263 - val_loss: 1.0486 - val_accuracy: 0.4082 - val_precision: 0.5370 - val_recall: 0.1480 - val_auc: 0.6476
# Epoch 30/50
# 25/25 [==============================] - 20s 688ms/step - loss: 0.9283 - accuracy: 0.5146 - precision: 0.7273 - recall: 0.2140 - auc: 0.7342 - val_loss: 1.0848 - val_accuracy: 0.4337 - val_precision: 0.4638 - val_recall: 0.1633 - val_auc: 0.6344
# Epoch 31/50
# 25/25 [==============================] - 21s 683ms/step - loss: 0.9554 - accuracy: 0.5083 - precision: 0.6573 - recall: 0.2076 - auc: 0.7153 - val_loss: 1.0353 - val_accuracy: 0.4388 - val_precision: 0.5652 - val_recall: 0.1327 - val_auc: 0.6483
# Epoch 32/50
# 25/25 [==============================] - 21s 725ms/step - loss: 0.9542 - accuracy: 0.5006 - precision: 0.7035 - recall: 0.2025 - auc: 0.7188 - val_loss: 1.0253 - val_accuracy: 0.4388 - val_precision: 0.6000 - val_recall: 0.1071 - val_auc: 0.6571
# Epoch 33/50
# 25/25 [==============================] - 22s 785ms/step - loss: 0.9474 - accuracy: 0.5172 - precision: 0.6872 - recall: 0.1987 - auc: 0.7213 - val_loss: 1.0280 - val_accuracy: 0.4490 - val_precision: 0.6452 - val_recall: 0.1020 - val_auc: 0.6536
# Epoch 34/50
# 25/25 [==============================] - 28s 933ms/step - loss: 0.9454 - accuracy: 0.5185 - precision: 0.7273 - recall: 0.1936 - auc: 0.7269 - val_loss: 1.0348 - val_accuracy: 0.4286 - val_precision: 0.6000 - val_recall: 0.1531 - val_auc: 0.6524
# Epoch 35/50
# 25/25 [==============================] - 20s 697ms/step - loss: 0.9363 - accuracy: 0.5185 - precision: 0.7303 - recall: 0.2242 - auc: 0.7269 - val_loss: 1.0758 - val_accuracy: 0.4286 - val_precision: 0.4848 - val_recall: 0.1633 - val_auc: 0.6330
# Epoch 36/50
# 25/25 [==============================] - 25s 848ms/step - loss: 0.9333 - accuracy: 0.5146 - precision: 0.7066 - recall: 0.2178 - auc: 0.7317 - val_loss: 1.0332 - val_accuracy: 0.4388 - val_precision: 0.5957 - val_recall: 0.1429 - val_auc: 0.6581
# Epoch 37/50
# 25/25 [==============================] - 16s 567ms/step - loss: 0.9256 - accuracy: 0.5274 - precision: 0.7296 - recall: 0.2166 - auc: 0.7357 - val_loss: 1.0382 - val_accuracy: 0.4235 - val_precision: 0.5600 - val_recall: 0.1429 - val_auc: 0.6543
# Epoch 38/50
# 25/25 [==============================] - 12s 410ms/step - loss: 0.9234 - accuracy: 0.5223 - precision: 0.7412 - recall: 0.2153 - auc: 0.7379 - val_loss: 1.0455 - val_accuracy: 0.4337 - val_precision: 0.5660 - val_recall: 0.1531 - val_auc: 0.6523
# Epoch 39/50
# 25/25 [==============================] - 12s 445ms/step - loss: 0.9175 - accuracy: 0.5274 - precision: 0.7240 - recall: 0.2306 - auc: 0.7403 - val_loss: 1.0349 - val_accuracy: 0.4286 - val_precision: 0.6042 - val_recall: 0.1480 - val_auc: 0.6600
# Epoch 40/50
# 25/25 [==============================] - 12s 440ms/step - loss: 0.9149 - accuracy: 0.5261 - precision: 0.7366 - recall: 0.2280 - auc: 0.7424 - val_loss: 1.0363 - val_accuracy: 0.4388 - val_precision: 0.5918 - val_recall: 0.1480 - val_auc: 0.6603
# Epoch 41/50
# 25/25 [==============================] - 15s 534ms/step - loss: 0.9194 - accuracy: 0.5210 - precision: 0.7083 - recall: 0.2382 - auc: 0.7387 - val_loss: 1.0258 - val_accuracy: 0.4490 - val_precision: 0.6667 - val_recall: 0.1122 - val_auc: 0.6540
# Epoch 42/50
# 25/25 [==============================] - 15s 521ms/step - loss: 0.9279 - accuracy: 0.5274 - precision: 0.7500 - recall: 0.1987 - auc: 0.7323 - val_loss: 1.0736 - val_accuracy: 0.4286 - val_precision: 0.4925 - val_recall: 0.1684 - val_auc: 0.6446
# Epoch 43/50
# 25/25 [==============================] - 15s 542ms/step - loss: 0.9172 - accuracy: 0.5287 - precision: 0.7422 - recall: 0.2420 - auc: 0.7419 - val_loss: 1.0233 - val_accuracy: 0.4490 - val_precision: 0.5909 - val_recall: 0.1327 - val_auc: 0.6610
# Epoch 44/50
# 25/25 [==============================] - 32s 1s/step - loss: 0.9128 - accuracy: 0.5248 - precision: 0.7362 - recall: 0.2204 - auc: 0.7419 - val_loss: 1.0713 - val_accuracy: 0.4337 - val_precision: 0.5000 - val_recall: 0.1684 - val_auc: 0.6489
# Epoch 45/50
# 25/25 [==============================] - 37s 1s/step - loss: 0.9139 - accuracy: 0.5236 - precision: 0.7176 - recall: 0.2331 - auc: 0.7426 - val_loss: 1.0231 - val_accuracy: 0.4490 - val_precision: 0.5897 - val_recall: 0.1173 - val_auc: 0.6635
# Epoch 46/50
# 25/25 [==============================] - 30s 939ms/step - loss: 0.9057 - accuracy: 0.5261 - precision: 0.7427 - recall: 0.2280 - auc: 0.7446 - val_loss: 1.0275 - val_accuracy: 0.4541 - val_precision: 0.6042 - val_recall: 0.1480 - val_auc: 0.6648
# Epoch 47/50
# 25/25 [==============================] - 28s 1s/step - loss: 0.8997 - accuracy: 0.5325 - precision: 0.7377 - recall: 0.2293 - auc: 0.7488 - val_loss: 1.0262 - val_accuracy: 0.4541 - val_precision: 0.5909 - val_recall: 0.1327 - val_auc: 0.6654
# Epoch 48/50
# 25/25 [==============================] - 31s 1s/step - loss: 0.9010 - accuracy: 0.5414 - precision: 0.7562 - recall: 0.2331 - auc: 0.7528 - val_loss: 1.0951 - val_accuracy: 0.4439 - val_precision: 0.5068 - val_recall: 0.1888 - val_auc: 0.6503
# Epoch 49/50
# 25/25 [==============================] - 27s 864ms/step - loss: 0.9281 - accuracy: 0.5172 - precision: 0.7046 - recall: 0.2127 - auc: 0.7338 - val_loss: 1.0290 - val_accuracy: 0.4490 - val_precision: 0.6000 - val_recall: 0.1224 - val_auc: 0.6595
# Epoch 50/50
# 25/25 [==============================] - 27s 1s/step - loss: 0.9107 - accuracy: 0.5350 - precision: 0.7477 - recall: 0.2115 - auc: 0.7441 - val_loss: 1.0261 - val_accuracy: 0.4541 - val_precision: 0.5909 - val_recall: 0.1327 - val_auc: 0.6629

# %%
# Load and test an image of curly hair
img_curly = keras.preprocessing.image.load_img(
    "../hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--layered-natural-hair-natural-black-hairstyles.jpg", target_size=image_size
)
img_array_curly = keras.preprocessing.image.img_to_array(img_curly)
img_array_curly = tf.expand_dims(img_array_curly, 0)  # Create batch axis

predictions_curly = model.predict(img_array_curly)
print(
    "CURLY: This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions_curly[0])
)

# Load and test an image of straight hair
img_straight = keras.preprocessing.image.load_img(
    "../hair_types/Straight_Hair/1-short-spiky-mens-haircut.jpg", target_size=image_size
)
img_array_straight = keras.preprocessing.image.img_to_array(img_straight)
img_array_straight = tf.expand_dims(img_array_straight, 0)  # Create batch axis

predictions_straight = model.predict(img_array_straight)
print(
    "STRAIGHT: This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions_straight[0])
)

# Load and test an image of wavy hair
img_wavy = keras.preprocessing.image.load_img(
    "../hair_types/Wavy_Hair/2-Short-High-Volume-Hairstyle.jpg", target_size=image_size
)
img_array_wavy = keras.preprocessing.image.img_to_array(img_wavy)
img_array_wavy = tf.expand_dims(img_array_wavy, 0)  # Create batch axis

predictions_wavy = model.predict(img_array_wavy)
print(
    "WAVY: This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions_wavy[0])
)
# Out:
# 1/1 [==============================] - 2s 2s/step
# CURLY: This image is 0.89 percent curly hair, 0.08 percent straight hair, and 0.03 percent wavy hair.
# 1/1 [==============================] - 0s 302ms/step
# STRAIGHT: This image is 0.12 percent curly hair, 0.43 percent straight hair, and 0.45 percent wavy hair.
# 1/1 [==============================] - 0s 357ms/step
# WAVY: This image is 0.14 percent curly hair, 0.41 percent straight hair, and 0.45 percent wavy hair.

# %%
import matplotlib.pyplot as plt

# Plot training history for loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Mark the best epoch for validation loss
best_epoch_loss = np.argmin(history.history['val_loss'])
plt.axvline(x=best_epoch_loss, color='r', linestyle='--', label=f'Best Epoch Loss: {best_epoch_loss}')
plt.legend()

# Plot training history for accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Mark the best epoch for validation accuracy
best_epoch_accuracy = np.argmax(history.history['val_accuracy'])
plt.axvline(x=best_epoch_accuracy, color='r', linestyle='--', label=f'Best Epoch Accuracy: {best_epoch_accuracy}')
plt.legend()

plt.tight_layout()
plt.show()

# %%
val_loss, val_accuracy = model.evaluate(val_ds)
# Out:
# 7/7 [==============================] - 5s 161ms/step - loss: 1.0261 - accuracy: 0.4541 - precision: 0.5909 - recall: 0.1327 - auc: 0.6629
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Andrea Dayo\Documents\GitHub\CS-ELEC-1A-LabEx\LabEx3\demo\discussion copy.ipynb Cell 13 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Andrea%20Dayo/Documents/GitHub/CS-ELEC-1A-LabEx/LabEx3/demo/discussion%20copy.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> val_loss, val_accuracy = model.evaluate(val_ds)
#
# ValueError: too many values to unpack (expected 2)

# %%
val_loss, val_accuracy, val_precision, val_recall, val_auc = model.evaluate(val_ds)
print(f"Validation Accuracy: {val_accuracy}")
print(f"Validation Precision: {val_precision}")
print(f"Validation Recall: {val_recall}")
print(f"Validation AUC: {val_auc}")
